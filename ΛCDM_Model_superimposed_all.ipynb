# %%
from numpy import pi, log, sqrt 
import getdist
import numpy as np
from io import StringIO
from getdist import plots, MCSamples
import random
from scipy.integrate import quad
from scipy.interpolate import interp1d
from scipy.integrate import odeint
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from scipy import stats
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior, GaussianPrior
import scipy.optimize as op
from numpy.linalg import inv
from mpi4py import MPI
import sympy as sp
import scipy.linalg as la
import pandas as pd

# %% [markdown]
# # Cosmic Chronometers Dataset with Full Covariance
#
# **Source:** [https://gitlab.com/mmoresco/CCcovariance](https://gitlab.com/mmoresco/CCcovariance)
#
# ### Description
#
# This analysis utilizes the Cosmic Chronometers (CC) dataset with the full covariance matrix and prepares the likelihood function for cosmological parameter estimation.
#
# ### Citation Guidelines
#
# If you use this dataset, please cite the following foundational works by Prof. Dr. Moresco:
#
# - Moresco et al. (2016), [arXiv:1804.05864](https://doi.org/10.48550/arXiv.1804.05864)
# - Moresco (2020), [arXiv:2003.07362](https://doi.org/10.48550/arXiv.2003.07362)
#
# Additionally, when using the same data, please acknowledge these important references:
#
# - Simon et al. (2005), [arXiv:1201.3609](https://doi.org/10.48550/arXiv.1201.3609)
# - Stern et al. (2010), [arXiv:1503.01116](https://doi.org/10.48550/arXiv.1503.01116)
# - Moresco et al. (2012), [arXiv:1601.01701](https://doi.org/10.48550/arXiv.1601.01701)

# %%
#Load CC dataset and Build Full Covariance Matrix
filename = 'datasets/Hubble_data/HzTable_MM_BC03.dat'
z, Hz, errHz = np.genfromtxt(filename, comments='#', usecols=(0,1,2), unpack=True, delimiter=',')
ref = np.genfromtxt(filename, comments='#', usecols=(3), unpack=True, dtype=str, delimiter=',')

filename = 'datasets/Hubble_data/data_MM20.dat'
zmod, imf, slib, sps, spsooo = np.genfromtxt(filename, comments='#', usecols=(0,1,2,3,4), unpack=True)

cov_mat_diag = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	cov_mat_diag[i,i] = errHz[i]**2

imf_intp = np.interp(z, zmod, imf)/100
slib_intp = np.interp(z, zmod, slib)/100
sps_intp = np.interp(z, zmod, sps)/100
spsooo_intp = np.interp(z, zmod, spsooo)/100

cov_mat_imf = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_slib = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_sps = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_spsooo = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	for j in range(len(z)):
		cov_mat_imf[i,j] = Hz[i] * imf_intp[i] * Hz[j] * imf_intp[j]
		cov_mat_slib[i,j] = Hz[i] * slib_intp[i] * Hz[j] * slib_intp[j]
		cov_mat_sps[i,j] = Hz[i] * sps_intp[i] * Hz[j] * sps_intp[j]
		cov_mat_spsooo[i,j] = Hz[i] * spsooo_intp[i] * Hz[j] * spsooo_intp[j]


cov_mat = cov_mat_spsooo+cov_mat_imf+cov_mat_diag
inv_cov_mat = inv(cov_mat)

cov_mat_cc = inv_cov_mat

# %% [markdown]
# # PantheonPlus Dataset (CosmoSIS Likelihood)
#
# **Source Link:** [Pantheon+ CosmoSIS Likelihood Script](https://github.com/PantheonPlusSH0ES/DataRelease/blob/main/Pantheon%2B_Data/5_COSMOLOGY/cosmosis_likelihoods/Pantheon%2B_only_cosmosis_likelihood.py)
# **Dataset Link:** [Pantheon+ Distances and Covariance](https://github.com/PantheonPlusSH0ES/DataRelease/tree/main/Pantheon%2B_Data/4_DISTANCES_AND_COVAR)
#
# ### Description
#
# This analysis utilizes the full **STAT+SYS** covariance matrix provided in the PantheonPlus data release to construct a supernova likelihood. The approach follows the CosmoSIS likelihood format and incorporates both statistical and systematic uncertainties in the SN Ia light curves.
#
# ### Citation Guidelines
#
# If you use this dataset or the associated likelihood script in your research, please cite the following key works:
#
# - **Pantheon+ Compilation and Analysis Methodology:**
#   - Brout et al. (2022), [arXiv:2112.03863](https://doi.org/10.48550/arXiv.2112.03863)
#   - Scolnic et al. (2022), [arXiv:2202.04077](https://doi.org/10.48550/arXiv.2202.04077)
#
# - **Covariance Matrix Construction:**
#   - Conley et al. (2011), [arXiv:1104.1443](https://doi.org/10.48550/arXiv.1104.1443)

# %%
#Load Pantheonplus dataset and Build the Covariance Matrix
values_filename = 'datasets/sn_data/PantheonPlus/Pantheon+SH0ES.dat'
cov_filename = 'datasets/sn_data/PantheonPlus/Pantheon+SH0ES_STAT+SYS.cov'

data = pd.read_csv(values_filename, sep=r'\s+')
origlen = len(data)
ww = (data['zHD'] > 0.01)  # Filter condition for zHD > 0.01
zcmb = data['zHD'][ww].values  # vpec corrected redshift (zCMB)
zhelio = data['zHEL'][ww].values  # Heliocentric redshift
mag = data['m_b_corr'][ww].values  # Corrected magnitudes
N = len(mag)

filename = cov_filename
#print("Loading covariance from {}".format(filename))
f = open(filename)
line = f.readline()
n = int(len(zcmb))
C = np.zeros((n,n))
ii = -1
jj = -1
mine = 999
maxe = -999
for i in range(origlen):
    jj = -1
    if ww[i]:
        ii += 1
    for j in range(origlen):
        if ww[j]:
            jj += 1
        val = float(f.readline())
        if ww[i]:
            if ww[j]:
                C[ii,jj] = val

f.close()
#print('Done')
cov = C
xdiag = 1/cov.diagonal()  # diagonal before marginalising constant
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
print("Pantheon SN: zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)
# Out:
# Pantheon SN: zmin=0.010160 zmax=2.261370 N=1590

# %% [markdown]
# # DESI DR2 Dataset with Full Covariance
#
# **Source of Dataset:**
# [DESI BAO Data - GitHub (CobayaSampler)](https://github.com/CobayaSampler/bao_data)
#
# ### Description
#
# This analysis utilizes incorporates the **DESI Data Release 2 (DR2)** dataset, which includes baryon acoustic oscillation (BAO) measurements derived from over 14 million galaxies and quasars. The full covariance matrix is used in the likelihood analysis to properly account for measurement uncertainties and correlations between data points.
#
# The dataset is made publicly available and formatted for direct use in cosmological inference frameworks such as [Cobaya](https://cobaya.readthedocs.io/) and [CosmoMC](https://cosmologist.info/cosmomc/).
#
# ### Citation Guidelines
#
# If you use this dataset in your work, please cite the following:
#
# - **DESI Collaboration (2025)** : _DESI DR2 Results II: Measurements of Baryon Acoustic Oscillations and Cosmological Constraints_ [arXiv:2503.14738] : (https://doi.org/10.48550/arXiv.2503.14738)

# %%
#loading BAO dataset with Covarinace matrix
dirBD= "datasets/DESI_DR2_data/desi_gaussian_bao_ALL_GCcomb_mean.txt"
BaoData = np.genfromtxt(dirBD)
xarr = np.array(BaoData[:,0])
yarr = np.array(BaoData[:,1])

funarr = np.genfromtxt(dirBD,dtype='str')[:,2]
print(funarr)

def modelArr(name):
    mod = []

    for j in range(len(funarr)):
        if (funarr[j] == name):
             mod.append([xarr[j],yarr[j]])
    mod = np.array(mod)
    mod = mod[np.argsort(mod[:,0])]
    return mod

cov_bao = np.loadtxt("datasets/DESI_DR2_data/desi_gaussian_bao_ALL_GCcomb_cov.txt")  
cov_bao_inv = np.linalg.inv(cov_bao)
# Out:
# ['DVrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd'
#  'DHrd' 'DHrd' 'DMrd']

# %% [markdown]
# 1. **Define the normalized Hubble function** $E(\theta, z)$:
#
# $$
# E(z) = \sqrt{\Omega_m (1 + z)^3 + (1 - \Omega_m)}
# $$
#
# 2. **The Hubble function** $H(\theta, z)$:
#
# $$
# H(z) = H_0 \times E(z)
# $$

# %%
#H functions
c = 299792.458

def E(theta,z):
    H0, Om, rd = theta
    OL = 1 - Om
    return np.sqrt(Om*(1+z)**3 + OL)

def H(theta,z):
    H0, Om, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(H0*E(theta,z[j]))
    arr = np.array(arr)
    return arr

H([67,0.32,147],[1,2,3])
# Out:
# array([120.6      , 204.5421228, 308.2      ])

# %% [markdown]
# 3. The comoving distance function $D_H(\theta, z)$:
#
# $$
# D_H(z) = \frac{c}{H(z)}
# $$
#
# 4. The comoving distance scaled by the sound horizon:
#
# $$
# \frac{D_H(z)}{r_d} = \frac{c}{H(z) \times r_d}
# $$

# %%
#DH functions
def DH(theta,z):
    H0, Om, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])))
    arr = np.array(arr)
    return arr

def DHrd(theta,z):
    H0, Om, rd = theta
    arr = []

    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])*rd))
    arr = np.array(arr)
    return arr

DHrd([67,0.32,147],[1,2,3])
# Out:
# array([16.91048488,  9.97058429,  6.61714626])

# %% [markdown]
# The Sk function $S_k(\theta, x)$:
#
# $$
# S_k(x) =
# \begin{cases}
# \frac{\sin\left(\sqrt{-\Omega_k} \, x\right)}{\sqrt{-\Omega_k}} & \text{if } \Omega_k < -10^{-15} \\
# \frac{\sinh\left(\sqrt{\Omega_k} \, x\right)}{\sqrt{\Omega_k}} & \text{if } \Omega_k > 10^{-15} \\
# x & \text{if } \Omega_k = 0
# \end{cases}
# $$
#
# Where:
#
# * $\Omega_k$ is the curvature parameter (based on the `Ok` variable in your function).
# * $x$ is the input variable in the function.
#
# This function evaluates different cases based on the sign and magnitude of $\Omega_k$ (denoted as `Ok`), using either the sine or hyperbolic sine functions, or returning $x$ when $\Omega_k = 0$.

# %%
def Sk(theta,x):
    H0, Om, rd = theta
    Ok =0
    if Ok < -10**(-15):
        return np.sin(np.sqrt(-Ok)*x)/np.sqrt(-Ok)
    #if Ok == 0:
    #    return x
    elif Ok > 10**(-15):
        return np.sinh(np.sqrt(Ok)*x)/np.sqrt(Ok)
    else:
        return x

# %% [markdown]
# **Derivative of $\chi$ with respect to $z$** :
#
# $$
# \frac{d\chi}{dz} = \frac{1}{E(\theta, z)}
# $$
#
# **Integral of $\chi$** :
#
# $$
# \chi(z) = \int_0^z \frac{dz'}{E(\theta, z')}
# $$

# %%
# function that returns dDC/dz,df/dz
def dchidz(x,z, H0, Om, rd):
    return 1/E([H0, Om, rd],z)

def chiInt(theta,z):
    H0, Om, rd = theta
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz,0,z,args=(H0, Om, rd,))
    return np.delete(arr ,0)

chiInt([67,0.32,147],[1,2,3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %% [markdown]
# 5. The comoving angular diameter distance is computed as: $D_M(\theta, z)$:
#
# $$
# D_M(z) = \frac{c}{H_0} \cdot S_k\left( \chi(z) \right)
# $$
#
# * $\chi(z) = \int_0^z \frac{c}{H(z')} \, dz'$ is the comoving radial distance
# * $S_k(\chi)$ accounts for spatial curvature:
#
# $$
# S_k(\chi) =
# \begin{cases}
# \frac{1}{\sqrt{\Omega_k}} \sinh\left(\sqrt{\Omega_k} \chi\right) & \text{if } \Omega_k > 0 \ (\text{open}) \\
# \chi & \text{if } \Omega_k = 0 \ (\text{flat}) \\
# \frac{1}{\sqrt{|\Omega_k|}} \sin\left(\sqrt{|\Omega_k|} \chi\right) & \text{if } \Omega_k < 0 \ (\text{closed})
# \end{cases}
# $$
#
# 6. The comoving angular diameter distance scaled by the sound horizon:
#
#
# $$
# \frac{D_M(z)}{r_d} = \frac{c}{H_0 \cdot r_d} \cdot S_k\left( \chi(z) \right)
# $$

# %%
#DM

def DM(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/H0)
    arr = np.array(arr)
    arr.shape
    return arr

def DMrd(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rd))
    arr = np.array(arr)
    arr.shape
    return arr

DMrd([67,0.32,147],[1,2,3])
# Out:
# array([23.20906838, 36.20292027, 44.31444763])

# %% [markdown]
# 7. The volume-averaged distance combines radial and transverse distances and is defined as:
#
# $$
# D_V(z) = \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3}
# $$
#
# * $D_H(z) = \dfrac{c}{H(z)}$: the comoving Hubble distance
# * $D_M(z)$: the comoving angular diameter distance
# * This is often used when the BAO measurement is spherically averaged.
#
# 8. The volume-averaged diameter distance scaled by the sound horizon:
#
# $$
# \frac{D_V(z)}{r_d} = \frac{ \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3} }{r_d}
# $$

# %%
#DV

def DV(theta,z):
    H0, Om, rd = theta
    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2))
    arr = np.array(arr)
    arr.shape
    return arr

def DVrd(theta,z):

    H0, Om, rd = theta

    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2)/rd)
    arr = np.array(arr)
    arr.shape
    return arr

DVrd([67,0.32,147],[1,2,3])
# Out:
# array([20.88448766, 29.67649485, 33.90737919])

# %% [markdown]
# ### Luminosity Distance
#
# $$
# D_L(z) = (1 + z) \cdot \frac{c \cdot \chi(z)}{H_0}
# $$
#
# ### Distance Modulus
#
# $$
# \mu(z) = 5 \log_{10} \left( D_L(z) \right) + 25
# $$

# %%
def DL(theta,z):
    H0, Om, rd = theta
    chi = chiInt(theta,z)
    return c*chi/H0

def mu(theta,z):
    H0, Om, rd = theta
    dL = DL(theta,z)
    mu = []

    for i in range(len(z)):
        mu.append(5*np.log10(dL[i]*(1+z[i])) + 25)
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def Omega_Lambda(theta):
    H0, Om, rd = theta
    OL = 1 - Om
    return OL

# %% [markdown]
# ### Log Likelihood Function for Cosmic Chronometer Measurements
#
# Given a model prediction $H(z; \theta)$, observed data $H_z$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2 = \left( H(z; \theta) - H_z \right)^T \cdot \mathbf{C}^{-1} \cdot \left( H(z; \theta) - H_z \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2
# $$
#
#
# ### Output Statistics
#
# The function also returns:
#
# * Minimum chi-squared: $\chi^2_{\text{min}}$
# * Total number of data points: $N$
# * Reduced chi-squared:
#
# $$
# \chi^2_{\text{red}} = \frac{\chi^2}{N - k}
# $$
#
# * $p$-value:
#
# $$
# p = 1 - F_{\chi^2}(\chi^2; \, \text{dof} = N - k)
# $$
#
# * Derived Cosmological Parameters:
#
# $$
# \Omega_\Lambda = 1 - \Omega_m \quad (\text{In the case Dark Energy Density })
# $$

# %%
def lnlike(theta,model,z,Hz,cov_mat_cc):
    prediction = model(theta,z)
    residualcc = prediction - Hz
    chi2 = residualcc.T @ cov_mat_cc @ residualcc
    return chi2

def lnlikeCC(theta):
    chi = 0; i = 0
    chi += lnlike(theta, H, z, Hz, cov_mat_cc)
    i += len(z)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCC([67,0.32,147]))
# Out:
# (np.float64(-6.183367402883178), [np.float64(6.183367402883178), np.float64(0.5152806169069315), np.float64(0.9065576943407061), 0.6799999999999999])

# %% [markdown]
# ### Log Likelihood Function for BAO Dataset with Full Covariance
#
# Given model predictions $\hat{y}_i = f_i(z_i; \theta)$ (e.g., BAO observables like $D_H$, $D_V$, and $D_A$, etc.), observed data $y_i$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2(\theta) = \left( \hat{y}(\theta) - y \right)^T \cdot \mathbf{C}^{-1} \cdot \left( \hat{y}(\theta) - y \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2(\theta)
# $$

# %%
# likelihood with covariance matrix
def lnlikecov(theta, model, x, y, cov):
    prediction = []

    for i in range(len(model)):
        fun = model[i]
        prediction.append(eval(fun)(theta, [x[i]]))
    prediction = np.array(prediction)[:, 0]
    vec = (prediction - y)
    result = np.dot(np.dot(vec, cov), vec.T)
    return result

print(lnlikecov([67, 0.32, 147], funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv))
# Out:
# 40.55527665589413

# %% [markdown]
# This function computes the log-likelihood of BAO data given cosmological parameters $\theta$. It calculates the chi-squared statistic comparing model predictions to observations using the inverse covariance matrix, then returns the negative chi-squared (log-likelihood), reduced chi-squared, p-value, and the derived parameter $\Omega_\Lambda$, providing a measure of fit quality and model consistency with the data.

# %%
def lnlikeBAO(theta):
    x = np.array(BaoData[:, 0])
    y = np.array(BaoData[:, 1])

    # Use your manually loaded inverse covariance matrix
    chi = lnlikecov(theta, funarr, x, y, cov_bao_inv)
    i = len(x)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi / (i - len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i - len(theta))), OL]

lnlikeBAO([67,0.32,147])
# Out:
# (np.float64(-40.55527665589413),
#  [np.float64(40.55527665589413),
#   np.float64(4.0555276655894135),
#   np.float64(1.352410060873055e-05),
#   0.6799999999999999])

# %% [markdown]
# ### Log Likelihood Function for PantheonPlus Dataset with Full Covariance
#
# In this analysis, I marginalize over the nuisance parameter $\mathcal{M}$ (the absolute magnitude offset) using the analytic approach described in Astier et al. (2001) [arXiv:astro-ph/0104009](https://arxiv.org/abs/astro-ph/0104009v1). The method uses the difference
#
# $$
# \Delta = 5 \log_{10} \left[d'_L(\theta, z_i)\right] - 5 \log_{10} \left[d'_L(\theta_{\text{true}}, z_i)\right]
# \quad \text{(Equation A.8)}
# $$
#
# where $d'_L$ is the luminosity distance.
#
# By construction, the minimized chi-squared at the true parameters satisfies
#
# $$
# \hat{\chi}^2_{\min} = \hat{\chi}^2(\theta_{\text{true}}) = 0.
# $$
#
# Assuming no prior knowledge of $M$, the likelihood is marginalized by integrating the general $\chi^2$ function over $M \in (-\infty, \infty)$:
#
# $$
# \tilde{\chi}^2 \equiv \chi^2_{M\text{-int}} = -2 \ln \left[\int_{-\infty}^{\infty} dM \exp\left(-\frac{1}{2} \chi^2 \right)\right]
# \quad \text{(Equation A.9)}
# $$
#
# This integral can be evaluated analytically to give:
#
# $$
# \tilde{\chi}^2 = \hat{\chi}^2 - \frac{B^2}{C} + \ln \left(\frac{C}{2 \pi}\right)
# \quad \text{(Equation A.10)}
# $$
#
# where
#
# $$
# B = \sum_{i=1}^n \frac{\Delta_i}{\sigma_i^2}
# \quad \text{(Equation A.11)}
# $$
#
# and
#
# $$
# C = \sum_{i=1}^n \frac{1}{\sigma_i^2}
# \quad \text{(Equation A.12)}
# $$
#
# Here, $\sigma_i^2$ are the variances from the covariance matrix.
#
# ### Reference
#
# ### Citation Guidelines
#
# If you use this liklihood in your work, please cite the following:
#
# - **Astier et al. (2001)** : _Supernovae and the Nature of the Dark Energy_ : [arXiv:astro-ph/0104009](https://arxiv.org/abs/astro-ph/0104009v1)

# %%
def A(theta, x, y, icov):
    Mu = mu(theta, x)
    residual = y - Mu 
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeSNIa(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeSNIa([67,0.32,147]))
# Out:
# (np.float64(-1413.3755759975), [np.float64(1413.3755759975), np.float64(0.8905958260853812), np.float64(0.9992887124194824), 0.6799999999999999])

# %% [markdown]
# $\mathcal{L}_{\text{CC + BAO}} = \mathcal{L}_{\text{CC}} \times \mathcal{L}_{\text{BAO}},$

# %%
def lnlikeCCBAO(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAO([67,0.32,147]))
# Out:
# (np.float64(-46.73864405877731), [np.float64(46.73864405877731), np.float64(1.8695457623510925), np.float64(0.005262801783734394), 0.6799999999999999])

# %% [markdown]
# $\mathcal{L}_{\text{CC + BAO + PP}} = \mathcal{L}_{\text{CC}} \times \mathcal{L}_{\text{BAO}} \times \mathcal{L}_{\text{PP}},$

# %%
def lnlikeCCBAOPP(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAOPP([67,0.32,147]))
# Out:
# (np.float64(-1460.1142200562772), [np.float64(1460.1142200562772), np.float64(0.9040954922949085), np.float64(0.9974903623427827), 0.6799999999999999])

# %%
runs = 150

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAO = PolyChordSettings(3,4)
settingsCCBAO.file_root = 'CC + DESI DR2'
settingsCCBAO.nlive = runs
settingsCCBAO.do_clustering = True
settingsCCBAO.read_resume = False

settingsCCBAOPP = PolyChordSettings(3,4)
settingsCCBAOPP.file_root = 'CC + DESI DR2 + PP'
settingsCCBAOPP.nlive = runs
settingsCCBAOPP.do_clustering = True
settingsCCBAOPP.read_resume = False

# %%
outputCCBAO = pypolychord.run_polychord(lnlikeCCBAO, 3,4, settingsCCBAO, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.3
#   release: 22nd Nov 2025
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     150
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + DESI DR2.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.117E-02 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 9.18292479e+01  1.13971407e-01  1.63062412e+02  5.06785262e+03
#   2.02714105e+02  0.00000000e+00  8.86028593e-01 -1.00000000e+30
#  -5.06785262e+03]
# _________________
# lives      | 150 |
# phantoms   |1339 |
# posteriors | 151 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 151
# nposterior =                 151
# nequals    =                   1
# nlike      =                3843
# <nlike>    =          24.62   (           1.64 per slice )
# log(Z)     =        -5074.21 +/-  0.83
# log(Z_1)   =        -5074.21 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 8.97789508e+01  2.00168057e-01  1.36756835e+02  1.46219917e+03
#   5.84879666e+01  0.00000000e+00  7.99831943e-01 -8.03269684e+03
#  -1.46219917e+03]
# _________________
# lives      | 150 |
# phantoms   |1907 |
# posteriors | 302 |
# equals     |   2 |
# Last dead point: [ 5.57867733e+01  4.01527019e-01  1.60999038e+02  4.81286001e+02
#   1.92514400e+01  0.00000000e+00  5.98472981e-01 -1.27995639e+03
#  -4.81286001e+02]
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 302
# nposterior =                 302
# nequals    =                   1
# nlike      =               10541
# <nlike>    =          44.65   (           2.98 per slice )
# log(Z)     =        -1469.05 +/-  0.67
# log(Z_1)   =        -1469.05 +/-  0.67 (still evaluating)
#
#
#
# _________________
# lives      | 150 |
# phantoms   |1904 |
# posteriors | 453 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 453
# nposterior =                 453
# nequals    =                   1
# nlike      =               17898
# <nlike>    =          49.05   (           3.27 per slice )
# log(Z)     =         -489.66 +/-  0.84
# log(Z_1)   =         -489.66 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [  87.07254037    0.38153828  107.80527751  171.94268237    6.87770729
#     0.            0.61846172 -240.07310664 -171.94268237]
# _________________
# lives      | 150 |
# phantoms   |1897 |
# posteriors | 604 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 604
# nposterior =                 604
# nequals    =                   1
# nlike      =               26339
# <nlike>    =          56.27   (           3.75 per slice )
# log(Z)     =         -180.61 +/-  0.60
# log(Z_1)   =         -180.61 +/-  0.60 (still evaluating)
#
#
#
# Last dead point: [ 6.27656026e+01  2.75702599e-01  1.67847608e+02  7.50387742e+01
#   3.00155097e+00  6.69230659e-07  7.24297401e-01 -8.87141411e+01
#  -7.50387742e+01]
# _________________
# lives      | 150 |
# phantoms   |1871 |
# posteriors | 755 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 755
# nposterior =                 755
# nequals    =                   3
# nlike      =               35484
# <nlike>    =          60.97   (           4.06 per slice )
# log(Z)     =          -84.23 +/-  0.45
# log(Z_1)   =          -84.23 +/-  0.45 (still evaluating)
#
#
#
# Last dead point: [ 8.83213524e+01  3.08845348e-01  1.13653038e+02  4.53853361e+01
#   1.81541344e+00  7.55577691e-03  6.91154652e-01 -8.70493910e+01
#  -4.53853361e+01]
# _________________
# lives      | 150 |
# phantoms   |2060 |
# posteriors | 906 |
# equals     |   8 |
# Last dead point:‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 906
# nposterior =                 906
# nequals    =                   8
# nlike      =               45360
# <nlike>    =          65.84   (           4.39 per slice )
# log(Z)     =          -54.29 +/-  0.33
# log(Z_1)   =          -54.29 +/-  0.33 (still evaluating)
#
#
#
#  [ 58.38647411   0.2776494  177.09761884  31.06307825   1.24252313
#    0.18693857   0.7223506  -50.54297602 -31.06307825]
# _________________
# lives      | 150 |
# phantoms   |2143 |
# posteriors |1045 |
# equals     |  12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1056
# nposterior =                1056
# nequals    =                   7
# nlike      =               56390
# <nlike>    =          73.53   (           4.90 per slice )
# log(Z)     =          -40.60 +/-  0.28
# log(Z_1)   =          -40.61 +/-  0.28 (still evaluating)
# log(Z_2)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 75.05419939   0.28392821 136.11714147  24.19986004   0.9679944
#    0.50785068   0.71607179 -24.93679503 -24.19986004]
# _________________
# lives      | 150 |
# phantoms   |2263 |
# posteriors |1196 |
# equals     |  40 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1207
# nposterior =                1207
# nequals    =                  42
# nlike      =               67442
# <nlike>    =          73.68   (           4.91 per slice )
# log(Z)     =          -33.69 +/-  0.24
# log(Z_1)   =          -33.69 +/-  0.24 (still evaluating)
# log(Z_2)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 73.31263939   0.30073506 138.69849037  20.16130127   0.80645205
#    0.73831364   0.69926494 -20.27412774 -20.16130127]
# _________________
# lives      | 150 |
# phantoms   |1988 |
# posteriors |1336 |
# equals     |  56 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1355
# nposterior =                1355
# nequals    =                  63
# nlike      =               78385
# <nlike>    =          72.95   (           4.86 per slice )
# log(Z)     =          -30.08 +/-  0.24
# log(Z_1)   =          -30.11 +/-  0.24 (still evaluating)
# log(Z_2)   =          -33.79 +/-  0.46
# log(Z_3)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 65.77743221   0.28998986 155.5124749   18.40689134   0.73627565
#    0.82463794   0.71001014 -33.39836874 -18.40689134]
# Last dead point:_________________
# lives      | 150 |
# phantoms   |2022 |
# posteriors |1487 |
# equals     | 153 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1506
# nposterior =                1506
# nequals    =                 149
# nlike      =               89195
# <nlike>    =          72.07   (           4.80 per slice )
# log(Z)     =          -28.47 +/-  0.24
# log(Z_1)   =          -28.48 +/-  0.24 (still evaluating)
# log(Z_2)   =          -33.79 +/-  0.46
# log(Z_3)   =          -45.05 +/-  0.64
#
#
#
#  [ 69.78876263   0.30179944 144.67996091  17.56525075   0.70261003
#    0.86028004   0.69820056 -17.67150418 -17.56525075]
# _________________
# lives      | 150 |
# phantoms   |2186 |
# posteriors |1638 |
# equals     | 285 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1657
# nposterior =                1657
# nequals    =                 266
# nlike      =               99920
# <nlike>    =          71.50   (           4.77 per slice )
# log(Z)     =          -27.79 +/-  0.24
# log(Z_1)   =          -27.80 +/-  0.24 (still evaluating)
# log(Z_2)   =          -33.79 +/-  0.46
# log(Z_3)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 68.1087037    0.30037616 149.00044959  17.04906752   0.6819627
#    0.88000632   0.69962384 -17.0979502  -17.04906752]
# _________________
# lives      | 150 |
# phantoms   |2008 |
# posteriors |1789 |
# equals     | 381 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1808
# nposterior =                1808
# nequals    =                 351
# nlike      =              110687
# <nlike>    =          71.78   (           4.79 per slice )
# log(Z)     =          -27.49 +/-  0.24
# log(Z_1)   =          -27.49 +/-  0.24 (still evaluating)
# log(Z_2)   =          -33.79 +/-  0.46
# log(Z_3)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 68.22836555   0.29401271 149.23000911  16.8034951    0.6721398
#    0.88879725   0.70598729 -17.3941189  -16.8034951 ]
# _______________________
# lives      | 149 |   1 |
# phantoms   |2007 |  73 |
# posteriors |1903 |1800 |
# equals     | 415 | 384 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                1950
# nposterior =                1950
# nequals    =                 406
# nlike      =              125181
# <nlike>    =          96.63   (           6.44 per slice )
# log(Z)     =          -27.36 +/-  0.25
# log(Z_1)   =          -27.60 +/-  0.25 (still evaluating)
# log(Z_2)   =          -29.52 +/-  0.25 (still evaluating)
# log(Z_3)   =          -29.70 +/-  0.26
# log(Z_4)   =          -33.79 +/-  0.46
# log(Z_5)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 68.83143616   0.2948553  147.79951843  16.70155822   0.66806233
#    0.89233226   0.7051447  -16.74461998 -16.70155822]
# _________________
# lives      | 150 |
# phantoms   |2289 |
# posteriors |2047 |
# equals     | 434 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                2095
# nposterior =                2095
# nequals    =                 427
# nlike      =              135789
# <nlike>    =          70.72   (           4.71 per slice )
# log(Z)     =          -27.31 +/-  0.25
# log(Z_1)   =          -27.54 +/-  0.25 (still evaluating)
# log(Z_2)   =          -29.50 +/-  0.25
# log(Z_3)   =          -29.70 +/-  0.26
# log(Z_4)   =          -33.79 +/-  0.46
# log(Z_5)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 68.84543998   0.29613142 147.58355042  16.63795477   0.66551819
#    0.89450384   0.70386858 -16.89904015 -16.63795477]
# _________________
# lives      | 150 |
# phantoms   |2074 |
# posteriors |2198 |
# equals     | 445 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                2246
# nposterior =                2246
# nequals    =                 435
# nlike      =              146604
# <nlike>    =          72.10   (           4.81 per slice )
# log(Z)     =          -27.29 +/-  0.25
# log(Z_1)   =          -27.51 +/-  0.25 (still evaluating)
# log(Z_2)   =          -29.50 +/-  0.25
# log(Z_3)   =          -29.70 +/-  0.26
# log(Z_4)   =          -33.79 +/-  0.46
# log(Z_5)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 69.09310595   0.29659903 147.07322049  16.60707435   0.66428297
#    0.89554871   0.70340097 -16.61842423 -16.60707435]
# _________________
# lives      | 150 |
# Last dead point: [ 68.87430538   0.29857012 147.33064081  16.59269329   0.66370773
#    0.8960332    0.70142988 -16.60181995 -16.59269329]
# phantoms   |1966 |
# posteriors |2349 |
# equals     | 447 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                2397
# nposterior =                2397
# nequals    =                 436
# nlike      =              157369
# <nlike>    =          71.77   (           4.78 per slice )
# log(Z)     =          -27.28 +/-  0.25
# log(Z_1)   =          -27.50 +/-  0.25 (still evaluating)
# log(Z_2)   =          -29.50 +/-  0.25
# log(Z_3)   =          -29.70 +/-  0.26
# log(Z_4)   =          -33.79 +/-  0.46
# log(Z_5)   =          -45.05 +/-  0.64
#
#
#
# _______________________
# lives      |  83 |  67 |
# phantoms   |1286 |1125 |
# posteriors |2412 |2431 |
# equals     | 447 | 450 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       7
# ndead      =                2548
# nposterior =                2548
# nequals    =                 439
# nlike      =              180970
# <nlike>    =         157.34   (          10.49 per slice )
# log(Z)     =          -27.28 +/-  0.25
# log(Z_1)   =          -28.13 +/-  0.25 (still evaluating)
# log(Z_2)   =          -28.33 +/-  0.25 (still evaluating)
# log(Z_3)   =          -29.50 +/-  0.25
# log(Z_4)   =          -29.70 +/-  0.26
# log(Z_5)   =          -30.90 +/-  0.27
# log(Z_6)   =          -33.79 +/-  0.46
# log(Z_7)   =          -45.05 +/-  0.64
#
#
#
# Last dead point: [ 68.78690947   0.29778814 147.58557055  16.57810825   0.66312433
#    0.89652319   0.70221186 -16.58903243 -16.57810825]
#  ____________________________________________________
# |                                                    |
# | ndead  =         2777                              |
# | log(Z) =          -27.27727 +/-            0.24694 |
# |____________________________________________________|

# %%
outputCCBAOPP = pypolychord.run_polychord(lnlikeCCBAOPP, 3,4, settingsCCBAOPP, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.3
#   release: 22nd Nov 2025
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     150
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + DESI DR2 + PP.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.239E-02 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 5.19618205e+01  4.73114837e-01  1.43111104e+02  8.00426745e+03
#   4.95620275e+00  0.00000000e+00  5.26885163e-01 -1.00000000e+30
#  -8.00426745e+03]
# _________________
# lives      | 150 |
# phantoms   |1401 |
# posteriors | 151 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 151
# nposterior =                 151
# nequals    =                   1
# nlike      =                3750
# <nlike>    =          24.00   (           1.60 per slice )
# log(Z)     =        -8010.63 +/-  0.83
# log(Z_1)   =        -8010.63 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 7.62478186e+01  8.38336922e-01  1.06623562e+02  3.30266397e+03
#   2.04499317e+00  0.00000000e+00  1.61663078e-01 -7.81672547e+03
#  -3.30266397e+03]
# _________________
# lives      | 150 |
# phantoms   |1998 |
# posteriors | 302 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 302
# nposterior =                 302
# nequals    =                   1
# nlike      =               10388
# <nlike>    =          44.25   (           2.95 per slice )
# log(Z)     =        -3310.03 +/-  0.84
# log(Z_1)   =        -3310.03 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 6.42897768e+01  5.34046981e-01  1.42522634e+02  2.12159239e+03
#   1.31367950e+00  2.22044605e-16  4.65953019e-01 -2.14559632e+03
#  -2.12159239e+03]
# _________________
# lives      | 150 |
# phantoms   |2172 |
# posteriors | 453 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 453
# nposterior =                 453
# nequals    =                   1
# nlike      =               17805
# <nlike>    =          49.45   (           3.30 per slice )
# log(Z)     =        -2129.82 +/-  0.78
# log(Z_1)   =        -2129.82 +/-  0.78 (still evaluating)
#
#
#
# Last dead point: [ 5.49951598e+01  4.34988169e-01  1.65918567e+02  1.65778506e+03
#   1.02649230e+00  2.24232257e-01  5.65011831e-01 -2.19355300e+03
#  -1.65778506e+03]
# _________________
# lives      | 150 |
# phantoms   |1965 |
# posteriors | 604 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 604
# nposterior =                 604
# nequals    =                   2
# nlike      =               26030
# <nlike>    =          54.83   (           3.66 per slice )
# log(Z)     =        -1666.21 +/-  0.54
# log(Z_1)   =        -1666.21 +/-  0.54 (still evaluating)
#
#
#
# Last dead point: [ 9.61303437e+01  3.51554159e-01  1.01647581e+02  1.52387325e+03
#   9.43574770e-01  9.47685439e-01  6.48445841e-01 -1.58495549e+03
#  -1.52387325e+03]
# _________________
# lives      | 150 |
# phantoms   |2033 |
# posteriors | 755 |
# equals     |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 755
# nposterior =                 755
# nequals    =                   2
# nlike      =               34833
# <nlike>    =          58.69   (           3.91 per slice )
# log(Z)     =        -1533.18 +/-  0.50
# log(Z_1)   =        -1533.18 +/-  0.50 (still evaluating)
#
#
#
# Last dead point: [ 6.28801123e+01  2.87531993e-01  1.60085499e+02  1.47563233e+03
#   9.13704227e-01  9.94043792e-01  7.12468007e-01 -1.52273825e+03
#  -1.47563233e+03]
# _________________
# lives      | 150 |
# phantoms   |2207 |
# posteriors | 906 |
# equals     |  10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 906
# nposterior =                 906
# nequals    =                  10
# nlike      =               44232
# <nlike>    =          62.66   (           4.18 per slice )
# log(Z)     =        -1484.58 +/-  0.34
# log(Z_1)   =        -1484.58 +/-  0.34 (still evaluating)
#
#
#
# Last dead point: [ 5.43625396e+01  2.90818453e-01  1.86963522e+02  1.45128302e+03
#   8.98627258e-01  9.98522430e-01  7.09181547e-01 -1.48118303e+03
#  -1.45128302e+03]
# _________________
# lives      | 150 |
# phantoms   |1932 |
# posteriors |1057 |
# equals     |  12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1057
# nposterior =                1057
# nequals    =                   8
# nlike      =               54470
# <nlike>    =          68.25   (           4.55 per slice )
# log(Z)     =        -1461.02 +/-  0.30
# log(Z_1)   =        -1461.02 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 7.07827283e+01  3.26230649e-01  1.40000566e+02  1.44127702e+03
#   8.92431593e-01  9.99216345e-01  6.73769351e-01 -1.45117802e+03
#  -1.44127702e+03]
# _______________________
# lives      | 149 |   1 |
# phantoms   |2062 |  26 |
# posteriors |1191 |1074 |
# equals     |  37 |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                1208
# nposterior =                1208
# nequals    =                  30
# nlike      =               66191
# <nlike>    =          78.14   (           5.21 per slice )
# log(Z)     =        -1450.64 +/-  0.25
# log(Z_1)   =        -1450.75 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1453.03 +/-  0.50 (still evaluating)
#
#
#
# Last dead point: [ 7.23729986e+01  2.98440210e-01  1.40917112e+02  1.43720630e+03
#   8.89911023e-01  9.99400869e-01  7.01559790e-01 -1.45071448e+03
#  -1.43720630e+03]
# _______________________
# lives      | 149 |   1 |
# phantoms   |2200 |  24 |
# posteriors |1326 |1202 |
# equals     |  61 |   3 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                1355
# nposterior =                1355
# nequals    =                  34
# nlike      =               77907
# <nlike>    =          78.11   (           5.21 per slice )
# log(Z)     =        -1447.13 +/-  0.25
# log(Z_1)   =        -1447.26 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1449.40 +/-  0.40 (still evaluating)
# log(Z_3)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.92112637e+01  3.11007957e-01  1.45741702e+02  1.43492181e+03
#   8.88496477e-01  9.99486053e-01  6.88992043e-01 -1.43623539e+03
#  -1.43492181e+03]
# _________________
# lives      | 150 |
# phantoms   |2084 |
# posteriors |1472 |
# equals     | 102 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1502
# nposterior =                1502
# nequals    =                 115
# nlike      =               88562
# <nlike>    =          71.03   (           4.74 per slice )
# log(Z)     =        -1445.30 +/-  0.24
# log(Z_1)   =        -1445.33 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1448.97 +/-  0.42
# log(Z_3)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 7.22504008e+01  3.00247378e-01  1.40333799e+02  1.43352732e+03
#   8.87633014e-01  9.99532428e-01  6.99752622e-01 -1.43717265e+03
#  -1.43352732e+03]
# _________________
# lives      | 150 |
# phantoms   |1949 |
# posteriors |1614 |
# equals     | 185 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =                1652
# nposterior =                1652
# nequals    =                 205
# nlike      =               99926
# <nlike>    =          75.76   (           5.05 per slice )
# log(Z)     =        -1444.25 +/-  0.25
# log(Z_1)   =        -1444.31 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1447.31 +/-  0.27
# log(Z_3)   =        -1448.97 +/-  0.42
# log(Z_4)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 7.12768472e+01  3.06142411e-01  1.41563859e+02  1.43297142e+03
#   8.87288807e-01  9.99549817e-01  6.93857589e-01 -1.43298118e+03
#  -1.43297142e+03]
# _________________
# lives      | 150 |
# phantoms   |2071 |
# posteriors |1765 |
# equals     | 306 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =                1803
# nposterior =                1803
# nequals    =                 325
# nlike      =              110713
# <nlike>    =          71.91   (           4.79 per slice )
# log(Z)     =        -1443.79 +/-  0.25
# log(Z_1)   =        -1443.83 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1447.31 +/-  0.27
# log(Z_3)   =        -1448.97 +/-  0.42
# log(Z_4)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.84481547e+01  3.05383991e-01  1.47674581e+02  1.43267279e+03
#   8.87103893e-01  9.99558911e-01  6.94616009e-01 -1.43316654e+03
#  -1.43267279e+03]
# _________________
# lives      | 150 |
# phantoms   |2121 |
# posteriors |1916 |
# equals     | 366 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =                1954
# nposterior =                1954
# nequals    =                 383
# nlike      =              121539
# <nlike>    =          72.17   (           4.81 per slice )
# log(Z)     =        -1443.60 +/-  0.25
# log(Z_1)   =        -1443.63 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1447.31 +/-  0.27
# log(Z_3)   =        -1448.97 +/-  0.42
# log(Z_4)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.73170013e+01  3.05727486e-01  1.49997596e+02  1.43251401e+03
#   8.87005580e-01  9.99563677e-01  6.94272514e-01 -1.43252145e+03
#  -1.43251401e+03]
# _______________________
# lives      |   3 | 147 |
# phantoms   |  53 |2193 |
# posteriors |1937 |2045 |
# equals     | 370 | 391 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       5
# ndead      =                2104
# nposterior =                2104
# nequals    =                 411
# nlike      =              134522
# <nlike>    =          86.55   (           5.77 per slice )
# log(Z)     =        -1443.52 +/-  0.25
# log(Z_1)   =        -1443.69 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1445.58 +/-  0.26 (still evaluating)
# log(Z_3)   =        -1447.31 +/-  0.27
# log(Z_4)   =        -1448.97 +/-  0.42
# log(Z_5)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.76524394e+01  3.06184445e-01  1.49113718e+02  1.43242672e+03
#   8.86951530e-01  9.99566277e-01  6.93815555e-01 -1.43244783e+03
#  -1.43242672e+03]
# _________________
# lives      | 150 |
# phantoms   |2089 |
# posteriors |2188 |
# equals     | 397 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       5
# ndead      =                2250
# nposterior =                2250
# nequals    =                 424
# nlike      =              145212
# <nlike>    =          71.27   (           4.75 per slice )
# log(Z)     =        -1443.49 +/-  0.25
# log(Z_1)   =        -1443.66 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1445.56 +/-  0.26
# log(Z_3)   =        -1447.31 +/-  0.27
# log(Z_4)   =        -1448.97 +/-  0.42
# log(Z_5)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.85870542e+01  3.02660789e-01  1.47431276e+02  1.43238231e+03
#   8.86924033e-01  9.99567594e-01  6.97339211e-01 -1.43242040e+03
#  -1.43238231e+03]
# _______________________
# lives      | 147 |   3 |
# phantoms   |2106 | 118 |
# posteriors |2302 |2205 |
# equals     | 401 | 397 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       7
# ndead      =                2395
# nposterior =                2395
# nequals    =                 428
# nlike      =              160816
# <nlike>    =         104.03   (           6.94 per slice )
# log(Z)     =        -1443.48 +/-  0.25
# log(Z_1)   =        -1443.88 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1445.56 +/-  0.26
# log(Z_3)   =        -1445.72 +/-  0.26 (still evaluating)
# log(Z_4)   =        -1446.12 +/-  0.26
# log(Z_5)   =        -1447.31 +/-  0.27
# log(Z_6)   =        -1448.97 +/-  0.42
# log(Z_7)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.78174829e+01  3.04162948e-01  1.48973832e+02  1.43236167e+03
#   8.86911250e-01  9.99568206e-01  6.95837052e-01 -1.43241739e+03
#  -1.43236167e+03]
# _________________
# lives      | 150 |
# phantoms   |2219 |
# posteriors |2443 |
# equals     | 401 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       7
# ndead      =                2539
# nposterior =                2539
# nequals    =                 433
# nlike      =              171217
# <nlike>    =          69.34   (           4.62 per slice )
# log(Z)     =        -1443.48 +/-  0.25
# log(Z_1)   =        -1443.88 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1445.56 +/-  0.26
# log(Z_3)   =        -1445.72 +/-  0.26
# log(Z_4)   =        -1446.12 +/-  0.26
# log(Z_5)   =        -1447.31 +/-  0.27
# log(Z_6)   =        -1448.97 +/-  0.42
# log(Z_7)   =        -1452.52 +/-  0.51
#
#
#
# Last dead point: [ 6.83465891e+01  3.04165585e-01  1.47797460e+02  1.43233691e+03
#   8.86895917e-01  9.99568937e-01  6.95834415e-01 -1.43235568e+03
#  -1.43233691e+03]
#  ____________________________________________________
# |                                                    |
# | ndead  =         2829                              |
# | log(Z) =        -1443.47682 +/-            0.25308 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAO.make_paramnames_files(paramnames)
outputCCBAOPP.make_paramnames_files(paramnames)

posteriorCCBAO = outputCCBAO.posterior
posteriorCCBAOPP = outputCCBAOPP.posterior
# Out:
# WARNING:root:outlier fraction 0.036661842739990354
# WARNING:root:outlier fraction 0.06293018682399214
# chains/CC + DESI DR2.txt
# Removed no burn in
# chains/CC + DESI DR2 + PP.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2'],title_limit=1)
#g.export("fig_a.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAOPP], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + PP'],title_limit=1)
#g.export("fig_b.pdf")
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - p
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAOPP']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAOPP
# H_{0} = 68.275515 +/- 2.836212 +/- 5.442084
# \Omega_{m0} = 0.304181 +/- 0.005019 +/- 0.011275
# r_d (Mpc) = 148.220027 +/- 6.215782 +/- 11.083410
# L = 1433.809462 +/- 1.063398 +/- 1.355019
# L/Dof = 0.887808 +/- 0.000658 +/- 0.000839
# p = 0.999522 +/- 0.000037 +/- 0.000121
# \Omega_{\Lambda0} = 0.695819 +/- 0.005507 +/- 0.010771

# %% [markdown]
# ### Here We Compute The Log Of Bayesian Evidence

# %%
outputCCBAOPP
# Out:
# Global evidence:
# log(Z)    -1443.476823 +/-  0.253082
#
# Local evidences:
# log(Z_1)    -1452.521309 +/-  0.513364
# log(Z_2)    -1448.971229 +/-  0.415077
# log(Z_3)    -1447.313183 +/-  0.274420
# log(Z_4)    -1445.563720 +/-  0.259272
# log(Z_5)    -1446.122503 +/-  0.263298
# log(Z_6)    -1445.719306 +/-  0.259881
# log(Z_7)    -1447.988144 +/-  0.298965
# log(Z_8)    -1447.090089 +/-  0.273012
# log(Z_9)    -1443.933054 +/-  0.254006
#
# Run-time information:
# ncluster           9
# nposterior      2829
# nequals          434
# ndead           2829
# nlive              0
# nlike         181742
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.830E+01 +/- 2.788E+00
# Om            \Omega_{m0}          3.040E-01 +/- 5.823E-03
# rd            r_d (Mpc)            1.482E+02 +/- 5.977E+00
# L             L                    1.434E+03 +/- 1.348E+00
# Ldof          L/Dof                8.879E-01 +/- 8.345E-04
# p             p                    9.995E-01 +/- 4.708E-05
# Omega_Lambda  \Omega_{\Lambda0}    6.960E-01 +/- 5.823E-03

# %% [markdown]
# $\Large \textbf{Union3}$
#
# $\textbf{Source Link:}$ https://github.com/dscolnic/Pantheon
#
# $\textbf{Dataset Link:}$ https://github.com/CobayaSampler/sn_data/tree/master/Union3
#
# In this analysis, I use the full $\texttt{STAT+SYS}$ covariance matrix in this analysis.
#
#
# ### Citation Guidelines
#
# If you use this dataset in your work, please cite the following:
#
# - **Unin3 (2025)** : _Union Through UNITY: Cosmology with 2,000 SNe Using a Unified Bayesian Framework_ : [arXiv:2311.12098](
#   https://doi.org/10.48550/arXiv.2311.12098)

# %%
#Load Union3 dataset and Build the Covariance Matrix
values_filename = 'datasets/sn_data/Union3/lcparam_full.txt'
cov_filename = 'datasets/sn_data/Union3/mag_covmat.txt'

da = np.loadtxt(values_filename, skiprows=1, usecols=(1, 2, 4))
zcmb = da[:, 0]
zhelio = da[:, 1]
mag = da[:, 2]
N = len(mag)
syscov = np.loadtxt(cov_filename, skiprows=1).reshape((N, N))
cov = np.copy(syscov)
xdiag = 1/cov.diagonal() 
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
print("Union3 : zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)
# Out:
# Union3 : zmin=0.050000 zmax=2.262260 N=22

# %%
# Define, E(z), dDC/dz, and df/dz

def E(theta,z):
    H0, Om, rd = theta
    OL = 1 - Om
    return np.sqrt(Om*(1+z)**3 + OL)

def dchidz_Union3(x,z, H0, Om, rd):
    return 1/E([H0, Om, rd],z)

def chiInt_Union3(theta,z):
    H0, Om, rd = theta
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz_Union3,0,z,args=(H0, Om, rd,))
    return np.delete(arr ,0)

chiInt_Union3([67,0.32,147],[1,2,3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %%
def DL(theta,z):
    H0, Om, rd = theta
    chi = chiInt_Union3(theta,z)
    return c*chi/H0

def mu_Union3(theta,z):
    H0, Om, rd = theta
    dL = DL(theta,z)
    mu = []

    for i in range(len(z)):
        mu.append(5*np.log10(dL[i]*(1+z[i])) + 25)
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def A(theta, x, y, icov):
    Mu = mu_Union3(theta, x)
    residual = y - Mu 
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeUnion3(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeUnion3([67,0.32,147]))
# Out:
# (np.float64(-28.84212400489636), [np.float64(28.84212400489636), np.float64(1.5180065265734926), np.float64(0.06850933302017703), 0.6799999999999999])

# %%
def lnlikeCCBAOUnion3(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAOUnion3([67,0.32,147]))
# Out:
# (np.float64(-75.58076806367367), [np.float64(75.58076806367367), np.float64(1.6081014481632696), np.float64(0.005136205521916737), 0.6799999999999999])

# %%
runs = 150

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAOUnion3 = PolyChordSettings(3,4)
settingsCCBAOUnion3.file_root = 'CC + DESI DR2 + Union3'
settingsCCBAOUnion3.nlive = runs
settingsCCBAOUnion3.do_clustering = True
settingsCCBAOUnion3.read_resume = False

# %%
outputCCBAOUnion3 = pypolychord.run_polychord(lnlikeCCBAOUnion3, 3,4, settingsCCBAOUnion3, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.3
#   release: 22nd Nov 2025
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     150
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + DESI DR2 + Union3.resume
#
# generating live points
#
#
# all live points generated
#
# Last dead point: [ 8.09851822e+01  9.84907049e-01  1.11213301e+02  5.90705458e+03
#   1.25682012e+02  0.00000000e+00  1.50929507e-02 -1.00000000e+30
#  -5.90705458e+03]
# Speed  1 =  0.163E-02 seconds
# number of repeats:           15
# started sampling
#
# _________________
# lives      | 150 |
# phantoms   |1445 |
# posteriors | 151 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 151
# nposterior =                 151
# nequals    =                   1
# nlike      =                3825
# <nlike>    =          24.50   (           1.63 per slice )
# log(Z)     =        -5913.42 +/-  0.83
# log(Z_1)   =        -5913.42 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 6.47116053e+01  4.92059896e-01  1.52900483e+02  1.46198648e+03
#   3.11060954e+01  0.00000000e+00  5.07940104e-01 -5.16728020e+03
#  -1.46198648e+03]
# _________________
# lives      | 150 |
# phantoms   |1791 |
# posteriors | 302 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 302
# nposterior =                 302
# nequals    =                   1
# nlike      =               10561
# <nlike>    =          44.91   (           2.99 per slice )
# log(Z)     =        -1469.33 +/-  0.83
# log(Z_1)   =        -1469.33 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 6.38096378e+01  5.06606748e-01  1.35274008e+02  5.19469664e+02
#   1.10525460e+01  0.00000000e+00  4.93393252e-01 -1.14186847e+03
#  -5.19469664e+02]
# _________________
# lives      | 150 |
# phantoms   |1904 |
# posteriors | 453 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 453
# nposterior =                 453
# nequals    =                   1
# nlike      =               18220
# <nlike>    =          51.06   (           3.40 per slice )
# log(Z)     =         -527.34 +/-  0.68
# log(Z_1)   =         -527.34 +/-  0.68 (still evaluating)
#
#
#
# Last dead point: [ 6.12594406e+01  4.27759337e-01  1.51943018e+02  2.00151472e+02
#   4.25854196e+00  0.00000000e+00  5.72240663e-01 -5.45870526e+02
#  -2.00151472e+02]
# _________________
# lives      | 150 |
# phantoms   |1791 |
# posteriors | 604 |
# equals     |   4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 604
# nposterior =                 604
# nequals    =                   3
# nlike      =               26698
# <nlike>    =          56.52   (           3.77 per slice )
# log(Z)     =         -207.92 +/-  0.44
# log(Z_1)   =         -207.92 +/-  0.44 (still evaluating)
#
#
#
# Last dead point: [ 8.67166101e+01  2.55062177e-01  1.22607807e+02  1.21111741e+02
#   2.57684555e+00  1.84369257e-08  7.44937823e-01 -1.57505724e+02
#  -1.21111741e+02]
# _________________
# lives      | 150 |
# phantoms   |2191 |
# posteriors | 755 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 755
# nposterior =                 755
# nequals    =                   4
# nlike      =               35736
# <nlike>    =          60.25   (           4.02 per slice )
# log(Z)     =         -130.23 +/-  0.49
# log(Z_1)   =         -130.23 +/-  0.49 (still evaluating)
#
#
#
# Last dead point: [ 5.85549872e+01  2.76886931e-01  1.74362834e+02  8.31737225e+01
#   1.76965367e+00  8.96631367e-04  7.23113069e-01 -9.82764574e+01
#  -8.31737225e+01]
# _______________________
# lives      | 141 |   9 |
# phantoms   |2145 | 193 |
# posteriors | 876 | 782 |
# equals     |   6 |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                 903
# nposterior =                 903
# nequals    =                   4
# nlike      =               47440
# <nlike>    =          78.03   (           5.20 per slice )
# log(Z)     =          -92.48 +/-  0.36
# log(Z_1)   =          -92.68 +/-  0.39 (still evaluating)
# log(Z_2)   =          -94.40 +/-  0.64 (still evaluating)
#
#
#
# Last dead point: [ 5.96383242e+01  2.96974049e-01  1.71925542e+02  6.53879037e+01
#   1.39123199e+00  3.91498075e-02  7.03025951e-01 -8.86942135e+01
#  -6.53879037e+01]
# _________________
# lives      | 150 |
# phantoms   |2146 |
# posteriors | 992 |
# equals     |  13 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1039
# nposterior =                1039
# nequals    =                  16
# nlike      =               58752
# <nlike>    =          75.41   (           5.03 per slice )
# log(Z)     =          -75.00 +/-  0.28
# log(Z_1)   =          -75.02 +/-  0.28 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 6.13197860e+01  3.21088829e-01  1.63336018e+02  5.68982867e+01
#   1.21060185e+00  1.52763376e-01  6.78911171e-01 -7.88813973e+01
#  -5.68982867e+01]
# _________________
# lives      | 150 |
# phantoms   |2187 |
# posteriors |1143 |
# equals     |  31 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1190
# nposterior =                1190
# nequals    =                  30
# nlike      =               69655
# <nlike>    =          72.69   (           4.85 per slice )
# log(Z)     =          -66.48 +/-  0.25
# log(Z_1)   =          -66.48 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 71.40185053   0.2914177  142.4295696   52.16540528   1.10990224
#    0.28006775   0.7085823  -60.42364189 -52.16540528]
# _________________
# lives      | 150 |
# phantoms   |1958 |
# posteriors |1294 |
# equals     |  47 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1341
# nposterior =                1341
# nequals    =                  54
# nlike      =               80544
# <nlike>    =          72.59   (           4.84 per slice )
# log(Z)     =          -62.28 +/-  0.25
# log(Z_1)   =          -62.28 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 67.68797495   0.29235201 150.73805287  50.30355928   1.0702885
#    0.34402491   0.70764799 -51.42911388 -50.30355928]
# _________________
# lives      | 150 |
# phantoms   |2138 |
# posteriors |1445 |
# equals     | 131 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1492
# nposterior =                1492
# nequals    =                 123
# nlike      =               91542
# <nlike>    =          73.32   (           4.89 per slice )
# log(Z)     =          -60.49 +/-  0.24
# log(Z_1)   =          -60.49 +/-  0.24 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 69.79961298   0.30494194 145.02070194  49.12068048   1.04512086
#    0.38816599   0.69505806 -49.28958848 -49.12068048]
# _________________
# lives      | 150 |
# phantoms   |1948 |
# posteriors |1596 |
# equals     | 242 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1643
# nposterior =                1643
# nequals    =                 237
# nlike      =              102389
# <nlike>    =          72.31   (           4.82 per slice )
# log(Z)     =          -59.63 +/-  0.25
# log(Z_1)   =          -59.63 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 71.15995908   0.30263455 142.0514123   48.59537941   1.03394424
#    0.40851608   0.69736545 -48.69327181 -48.59537941]
# _________________
# lives      | 150 |
# phantoms   |1981 |
# posteriors |1747 |
# equals     | 362 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1794
# nposterior =                1794
# nequals    =                 353
# nlike      =              113207
# <nlike>    =          72.12   (           4.81 per slice )
# log(Z)     =          -59.24 +/-  0.25
# log(Z_1)   =          -59.24 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 68.5882456    0.2999149  147.79884657  48.32579487   1.0282084
#    0.41911767   0.7000851  -48.41900294 -48.32579487]
# _________________
# lives      | 150 |
# phantoms   |2062 |
# posteriors |1898 |
# equals     | 425 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                1945
# nposterior =                1945
# nequals    =                 414
# nlike      =              124098
# <nlike>    =          72.61   (           4.84 per slice )
# log(Z)     =          -59.08 +/-  0.25
# log(Z_1)   =          -59.08 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 67.94259444   0.30690018 148.37566878  48.19850274   1.02550006
#    0.42415825   0.69309982 -48.71694415 -48.19850274]
# _________________
# lives      | 150 |
# phantoms   |2071 |
# posteriors |2049 |
# equals     | 447 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2096
# nposterior =                2096
# nequals    =                 445
# nlike      =              134889
# <nlike>    =          71.94   (           4.80 per slice )
# log(Z)     =          -59.02 +/-  0.25
# log(Z_1)   =          -59.02 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 69.33101612   0.30352852 145.81738759  48.13813424   1.02421562
#    0.42655626   0.69647148 -48.18742457 -48.13813424]
# _________________
# lives      | 150 |
# phantoms   |2155 |
# posteriors |2200 |
# equals     | 462 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2247
# nposterior =                2247
# nequals    =                 454
# nlike      =              145719
# <nlike>    =          72.20   (           4.81 per slice )
# log(Z)     =          -58.99 +/-  0.25
# log(Z_1)   =          -58.99 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 68.99533735   0.30294641 146.54637638  48.1061643    1.02353541
#    0.42782812   0.69705359 -48.13180944 -48.1061643 ]
# _________________
# lives      | 150 |
# phantoms   |2151 |
# posteriors |2351 |
# equals     | 468 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2398
# nposterior =                2398
# nequals    =                 457
# nlike      =              156570
# <nlike>    =          72.34   (           4.82 per slice )
# log(Z)     =          -58.98 +/-  0.25
# log(Z_1)   =          -58.98 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 67.94597937   0.30360747 148.72427053  48.09018191   1.02319536
#    0.42846443   0.69639253 -48.09168615 -48.09018191]
# _________________
# lives      | 150 |
# phantoms   |2156 |
# posteriors |2502 |
# equals     | 471 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2549
# nposterior =                2549
# nequals    =                 459
# nlike      =              167418
# <nlike>    =          72.32   (           4.82 per slice )
# log(Z)     =          -58.98 +/-  0.25
# log(Z_1)   =          -58.98 +/-  0.25 (still evaluating)
# log(Z_2)   =          -79.57 +/-  0.52
# log(Z_3)   =          -79.88 +/-  0.69
#
#
#
# Last dead point: [ 68.44715181   0.304152   147.5851011   48.07187641   1.02280588
#    0.42919364   0.695848   -48.09286007 -48.07187641]
#  ____________________________________________________
# |                                                    |
# | ndead  =         2809                              |
# | log(Z) =          -58.97768 +/-            0.25033 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAOUnion3.make_paramnames_files(paramnames)

posteriorCCBAOUnion3 = outputCCBAOUnion3.posterior
# Out:
# WARNING:root:outlier fraction 0.045608927704997575
# chains/CC + DESI DR2 + Union3.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAOUnion3], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + Union3'],title_limit=1)
#g.export("fig_d.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAOUnion3']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAOUnion3
# H_{0} = 68.373437 +/- 2.790502 +/- 5.301783
# \Omega_{m0} = 0.303925 +/- 0.005562 +/- 0.010652
# r_d (Mpc) = 148.035790 +/- 5.878181 +/- 12.119896
# L = 49.517655 +/- 1.080695 +/- 1.353035
# L/Dof = 1.053567 +/- 0.022994 +/- 0.028788
# p = 0.374448 +/- 0.043350 +/- 0.103793
# \Omega_{\Lambda0} = 0.696075 +/- 0.005434 +/- 0.011251

# %%
outputCCBAOUnion3
# Out:
# Global evidence:
# log(Z)    -58.977684 +/-  0.250329
#
# Local evidences:
# log(Z_1)    -79.875917 +/-  0.691930
# log(Z_2)    -79.569908 +/-  0.517769
# log(Z_3)    -58.977684 +/-  0.250329
#
# Run-time information:
# ncluster           3
# nposterior      2809
# nequals          461
# ndead           2809
# nlive              0
# nlike         175460
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.827E+01 +/- 2.747E+00
# Om            \Omega_{m0}          3.039E-01 +/- 5.412E-03
# rd            r_d (Mpc)            1.483E+02 +/- 6.024E+00
# L             L                    4.948E+01 +/- 1.159E+00
# Ldof          L/Dof                1.053E+00 +/- 2.465E-02
# p             p                    3.756E-01 +/- 4.193E-02
# Omega_Lambda  \Omega_{\Lambda0}    6.961E-01 +/- 5.412E-03

# %% [markdown]
# $\Large \textbf{DES DovekieLike Supernova}$
#
# $\textbf{Source Link:}$ https://github.com/des-science/DES-SN5YR/blob/main/5_COSMOLOGY/Dovekie_cosmosis_likelihood.py
#
# In this analysis, I use the full $\texttt{STAT+SYS}$ covariance matrix in this analysis.

# %%
#loading DES DovekieLike dataset with Covarinace matrix
values_filename = 'datasets/sn_data/DES-Dovekie/DES-Dovekie_HD.csv'
cov_filename    = 'datasets/sn_data/DES-Dovekie/covtot_inv_000.npz'

da = pd.read_csv(values_filename)
zcmb   = da['zHD'].values
zhelio = da['zHEL'].values
mag    = da['MU'].values
N = len(mag)

def read_inv_covmat(filename):
    d = np.load(filename)
    n = int(d[d.files[0]][0])
    inv_cov = np.zeros((n, n))
    inv_cov[np.triu_indices(n)] = d[d.files[1]]
    i_lower = np.tril_indices(n, -1)
    inv_cov[i_lower] = inv_cov.T[i_lower]
    return inv_cov

icov = read_inv_covmat(cov_filename)
cov = la.inv(icov)
xdiag = 1.0 / cov.diagonal()
zmin  = zcmb.min()
zmax  = zcmb.max()
zmaxi = 1.1
print("DES-Dovekie: zmin = %.5f  zmax = %.5f  N = %d" % (zmin, zmax, N))
ninterp = 150
zinter  = np.linspace(1e-3, zmaxi, ninterp)
# Out:
# DES-Dovekie: zmin = 0.02509  zmax = 1.14418  N = 1820

# %%
# Define, E(z), dDC/dz, and df/dz

def E(theta,z):
    H0, Om, rd = theta
    OL = 1 - Om
    return np.sqrt(Om*(1+z)**3 + OL)

def dchidz_DES(x,z, H0, Om, rd):
    return 1/E([H0, Om, rd],z)

def chiInt_DES(theta,z):
    H0, Om, rd = theta
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz_DES,0,z,args=(H0, Om, rd,))
    return np.delete(arr ,0)

chiInt_DES([67,0.32,147],[1,2,3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %%
def DL(theta,z):
    H0, Om, rd = theta
    chi = chiInt_DES(theta,z)
    return c*chi/H0

def mu_DES(theta,z):
    H0, Om, rd = theta
    dL = DL(theta,z)
    mu = []

    for i in range(len(z)):
        mu.append(5*np.log10(dL[i]*(1+z[i])) + 25)
    mu = np.array(mu)
    mu.shape
    return mu

# %%
def A(theta, x, y, icov):
    Mu = mu_DES(theta, x)
    residual = y - Mu 
    chit2 = residual.T @ icov @ residual
    B = np.sum(residual @ icov)
    C = np.sum(icov)
    chi2 = chit2 - (B**2 / C) + np.log(C / (2 * np.pi))
    return chi2

def lnlikeDES(theta):
    chi = A(theta, zcmb, mag, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)),1-stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeDES([67,0.32,147]))
# Out:
# (np.float64(-1640.9534687726277), [np.float64(1640.9534687726277), np.float64(0.9031114302546107), np.float64(0.9986904628020256), 0.6799999999999999])

# %%
def lnlikeCCBAODES(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mag, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1 - stats.chi2.cdf(x=chi, df=(i-len(theta))),OL]

print(lnlikeCCBAODES([67,0.32,147]))
# Out:
# (np.float64(-1687.692112831405), [np.float64(1687.692112831405), np.float64(0.9147382725373469), np.float64(0.9960470661281187), 0.6799999999999999])

# %%
runs = 150

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.,100.)(hypercube[0]))
    prior.append(UniformPrior(0.,1.)(hypercube[1]))
    prior.append(UniformPrior(100.,200.)(hypercube[2]))
    return prior

# %%
settingsCCBAODES = PolyChordSettings(3,4)
settingsCCBAODES.file_root = 'CC + DESI DR2 + DES-DovekieLike'
settingsCCBAODES.nlive = runs
settingsCCBAODES.do_clustering = True
settingsCCBAODES.read_resume = False

# %%
outputCCBAODES = pypolychord.run_polychord(lnlikeCCBAODES, 3,4, settingsCCBAODES, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.3
#   release: 22nd Nov 2025
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     150
# nDims    :       3
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + DESI DR2 + DES-DovekieLike.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.474E-02 seconds
# number of repeats:           15
# started sampling
#
# Last dead point: [ 6.39029476e+01  5.29483805e-01  1.71792923e+02  7.23136140e+03
#   3.91943707e+00  0.00000000e+00  4.70516195e-01 -1.00000000e+30
#  -7.23136140e+03]
# _________________
# lives      | 150 |
# phantoms   |1353 |
# posteriors | 151 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 151
# nposterior =                 151
# nequals    =                   1
# nlike      =                3796
# <nlike>    =          24.31   (           1.62 per slice )
# log(Z)     =        -7237.72 +/-  0.83
# log(Z_1)   =        -7237.72 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 6.77668593e+01  6.79165059e-01  1.27954705e+02  3.05453361e+03
#   1.65557377e+00  0.00000000e+00  3.20834941e-01 -1.00000000e+30
#  -3.05453361e+03]
# _________________
# lives      | 150 |
# phantoms   |1724 |
# posteriors | 302 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 302
# nposterior =                 302
# nequals    =                   1
# nlike      =               10483
# <nlike>    =          44.58   (           2.97 per slice )
# log(Z)     =        -3061.86 +/-  0.82
# log(Z_1)   =        -3061.86 +/-  0.82 (still evaluating)
#
#
#
# Last dead point: [ 8.30142854e+01  2.88487033e-01  1.31059054e+02  2.14888328e+03
#   1.16470638e+00  9.56257437e-07  7.11512967e-01 -2.62540388e+03
#  -2.14888328e+03]
# _________________
# lives      | 150 |
# phantoms   |1873 |
# posteriors | 453 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 453
# nposterior =                 453
# nequals    =                   1
# nlike      =               18211
# <nlike>    =          51.52   (           3.43 per slice )
# log(Z)     =        -2156.44 +/-  0.58
# log(Z_1)   =        -2156.44 +/-  0.58 (still evaluating)
#
#
#
# Last dead point: [ 8.72203467e+01  2.21516616e-01  1.22774346e+02  1.85993603e+03
#   1.00809541e+00  3.98903404e-01  7.78483384e-01 -3.51855136e+03
#  -1.85993603e+03]
# _________________
# lives      | 150 |
# phantoms   |2138 |
# posteriors | 604 |
# equals     |   2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 604
# nposterior =                 604
# nequals    =                   2
# nlike      =               26560
# <nlike>    =          55.66   (           3.71 per slice )
# log(Z)     =        -1868.44 +/-  0.60
# log(Z_1)   =        -1868.44 +/-  0.60 (still evaluating)
#
#
#
# Last dead point: [ 7.44244504e+01  2.69781064e-01  1.36716495e+02  1.74141161e+03
#   9.43854529e-01  9.57939871e-01  7.30218936e-01 -1.74500553e+03
#  -1.74141161e+03]
# _________________
# lives      | 150 |
# phantoms   |2105 |
# posteriors | 755 |
# equals     |   5 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 755
# nposterior =                 755
# nequals    =                   5
# nlike      =               35444
# <nlike>    =          59.23   (           3.95 per slice )
# log(Z)     =        -1749.77 +/-  0.38
# log(Z_1)   =        -1749.77 +/-  0.38 (still evaluating)
#
#
#
# Last dead point: [ 5.75919776e+01  3.32774613e-01  1.73805478e+02  1.69642493e+03
#   9.19471505e-01  9.93855551e-01  6.67225387e-01 -1.70672856e+03
#  -1.69642493e+03]
# _________________
# lives      | 150 |
# phantoms   |2047 |
# posteriors | 906 |
# equals     |   7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 906
# nposterior =                 906
# nequals    =                   6
# nlike      =               45020
# <nlike>    =          63.84   (           4.26 per slice )
# log(Z)     =        -1705.59 +/-  0.33
# log(Z_1)   =        -1705.59 +/-  0.33 (still evaluating)
#
#
#
# Last dead point: [ 8.21742584e+01  2.92972773e-01  1.23267644e+02  1.67916590e+03
#   9.10117021e-01  9.97486489e-01  7.07027227e-01 -1.68480934e+03
#  -1.67916590e+03]
# _________________
# lives      | 150 |
# phantoms   |2225 |
# posteriors |1057 |
# equals     |  24 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1057
# nposterior =                1057
# nequals    =                  18
# nlike      =               55395
# <nlike>    =          69.17   (           4.61 per slice )
# log(Z)     =        -1688.20 +/-  0.26
# log(Z_1)   =        -1688.20 +/-  0.26 (still evaluating)
#
#
#
# Last dead point: [ 5.80064563e+01  3.05034910e-01  1.74809136e+02  1.66990832e+03
#   9.05099361e-01  9.98500837e-01  6.94965090e-01 -1.67946119e+03
#  -1.66990832e+03]
# _________________
# lives      | 150 |
# phantoms   |2182 |
# posteriors |1208 |
# equals     |  32 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1208
# nposterior =                1208
# nequals    =                  25
# nlike      =               66349
# <nlike>    =          73.03   (           4.87 per slice )
# log(Z)     =        -1679.60 +/-  0.25
# log(Z_1)   =        -1679.60 +/-  0.25 (still evaluating)
#
#
#
# Last dead point: [ 7.21188462e+01  3.12177955e-01  1.38488599e+02  1.66579821e+03
#   9.02871656e-01  9.98818284e-01  6.87822045e-01 -1.66768688e+03
#  -1.66579821e+03]
# _________________
# lives      | 150 |
# phantoms   |2288 |
# posteriors |1335 |
# equals     |  46 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1351
# nposterior =                1351
# nequals    =                  20
# nlike      =               77513
# <nlike>    =          74.43   (           4.96 per slice )
# log(Z)     =        -1675.79 +/-  0.25
# log(Z_1)   =        -1675.93 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 7.10400086e+01  3.15672555e-01  1.40742430e+02  1.66296774e+03
#   9.01337530e-01  9.98999961e-01  6.84327445e-01 -1.66587370e+03
#  -1.66296774e+03]
# _________________
# lives      | 150 |
# phantoms   |2090 |
# posteriors |1486 |
# equals     |  93 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1502
# nposterior =                1502
# nequals    =                  86
# nlike      =               88435
# <nlike>    =          72.81   (           4.85 per slice )
# log(Z)     =        -1673.49 +/-  0.25
# log(Z_1)   =        -1673.51 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 7.11641893e+01  2.99023356e-01  1.42432237e+02  1.66165547e+03
#   9.00626269e-01  9.99075227e-01  7.00976644e-01 -1.66743398e+03
#  -1.66165547e+03]
# _________________
# lives      | 150 |
# phantoms   |2025 |
# posteriors |1637 |
# equals     | 202 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       2
# ndead      =                1653
# nposterior =                1653
# nequals    =                 200
# nlike      =               99120
# <nlike>    =          71.23   (           4.75 per slice )
# log(Z)     =        -1672.36 +/-  0.25
# log(Z_1)   =        -1672.36 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 7.05918608e+01  3.02336908e-01  1.43220269e+02  1.66092428e+03
#   9.00229965e-01  9.99114887e-01  6.97663092e-01 -1.66156584e+03
#  -1.66092428e+03]
# _______________________
# lives      | 141 |   9 |
# phantoms   |1815 | 158 |
# posteriors |1747 |1675 |
# equals     | 285 | 182 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                1801
# nposterior =                1801
# nequals    =                 264
# nlike      =              114969
# <nlike>    =         105.66   (           7.04 per slice )
# log(Z)     =        -1671.86 +/-  0.25
# log(Z_1)   =        -1672.17 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1673.19 +/-  0.26 (still evaluating)
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.71148307e+01  3.08686684e-01  1.49870973e+02  1.66069058e+03
#   9.00103296e-01  9.99127233e-01  6.91313316e-01 -1.66089672e+03
#  -1.66069058e+03]
# _______________________
# lives      | 146 |   4 |
# phantoms   |2310 | 108 |
# posteriors |1888 |1684 |
# equals     | 361 | 184 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       3
# ndead      =                1951
# nposterior =                1951
# nequals    =                 303
# nlike      =              128690
# <nlike>    =          91.47   (           6.10 per slice )
# log(Z)     =        -1671.66 +/-  0.25
# log(Z_1)   =        -1671.94 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1673.08 +/-  0.26 (still evaluating)
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.96102897e+01  3.07200614e-01  1.44813723e+02  1.66053422e+03
#   9.00018550e-01  9.99135404e-01  6.92799386e-01 -1.66058536e+03
#  -1.66053422e+03]
# _________________
# lives      | 150 |
# phantoms   |2001 |
# posteriors |2023 |
# equals     | 385 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2091
# nposterior =                2091
# nequals    =                 327
# nlike      =              139258
# <nlike>    =          70.45   (           4.70 per slice )
# log(Z)     =        -1671.58 +/-  0.25
# log(Z_1)   =        -1671.85 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1673.04 +/-  0.26
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.74590726e+01  3.04667830e-01  1.49675916e+02  1.66046511e+03
#   8.99981089e-01  9.99138994e-01  6.95332170e-01 -1.66047910e+03
#  -1.66046511e+03]
# _________________
# lives      | 150 |
# phantoms   |2165 |
# posteriors |2174 |
# equals     | 394 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2242
# nposterior =                2242
# nequals    =                 333
# nlike      =              150062
# <nlike>    =          72.03   (           4.80 per slice )
# log(Z)     =        -1671.55 +/-  0.25
# log(Z_1)   =        -1671.81 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1673.04 +/-  0.26
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.77115130e+01  3.05394583e-01  1.49088306e+02  1.66042434e+03
#   8.99958992e-01  9.99141105e-01  6.94605417e-01 -1.66372163e+03
#  -1.66042434e+03]
# _________________
# lives      | 150 |
# phantoms   |1969 |
# posteriors |2325 |
# equals     | 401 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2393
# nposterior =                2393
# nequals    =                 335
# nlike      =              161034
# <nlike>    =          73.15   (           4.88 per slice )
# log(Z)     =        -1671.54 +/-  0.25
# log(Z_1)   =        -1671.79 +/-  0.25 (still evaluating)
# log(Z_2)   =        -1673.04 +/-  0.26
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.87418670e+01  3.06545496e-01  1.46698127e+02  1.66040460e+03
#   8.99948291e-01  9.99142125e-01  6.93454504e-01 -1.66043622e+03
#  -1.66040460e+03]
# _________________
# lives      | 150 |
# phantoms   |2113 |
# posteriors |2476 |
# equals     | 401 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       3
# ndead      =                2544
# nposterior =                2544
# nequals    =                 335
# nlike      =              171910
# <nlike>    =          72.51   (           4.83 per slice )
# log(Z)     =        -1671.53 +/-  0.25
# log(Z_1)   =        -1671.79 +/-  0.26 (still evaluating)
# log(Z_2)   =        -1673.04 +/-  0.26
# log(Z_3)   =        -1677.91 +/-  0.39
#
#
#
# Last dead point: [ 6.82687286e+01  3.05769715e-01  1.47787396e+02  1.66038404e+03
#   8.99937152e-01  9.99143187e-01  6.94230285e-01 -1.66040027e+03
#  -1.66038404e+03]
#  ____________________________________________________
# |                                                    |
# | ndead  =         2837                              |
# | log(Z) =        -1671.53089 +/-            0.25431 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAODES.make_paramnames_files(paramnames)

posteriorCCBAODES = outputCCBAODES.posterior
# Out:
# WARNING:root:outlier fraction 0.056174334140435836
# chains/CC + DESI DR2 + DES-DovekieLike.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAODES], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['darkblue','red','purple'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + DES SN5YR'],title_limit=1)
#g.export("fig_e.pdf")
# Out:
# WARNING:root:fine_bins not large enough to well sample smoothing scale - p
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
g = getdist.plots.getSubplotPlotter(width_inch=5.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.8  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 12  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 12  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAO,posteriorCCBAOPP,posteriorCCBAOUnion3,posteriorCCBAODES], ('H0','Om','Omega_Lambda','rd') ,filled=True, contour_colors=['royalblue', 'orangered', 'darkviolet', 'darkblue'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2', r'CC + DESI DR2 + PP', r'CC + DESI DR2 + Union3', r'CC + DESI DR2 + DES-DovekieLike'])
g.export("Plots/Combine_Posteriors.pdf")
# Out:
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda
# WARNING:root:Parameters are 100% correlated: Om, Omega_Lambda

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAODES']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAODES
# H_{0} = 68.342037 +/- 2.612905 +/- 5.482792
# \Omega_{m0} = 0.305644 +/- 0.005011 +/- 0.009984
# r_d (Mpc) = 147.893955 +/- 5.728349 +/- 10.426916
# L = 1661.764863 +/- 1.009990 +/- 1.283879
# L/Dof = 0.900686 +/- 0.000547 +/- 0.000696
# p = 0.999067 +/- 0.000053 +/- 0.000198
# \Omega_{\Lambda0} = 0.694356 +/- 0.005045 +/- 0.011436

# %%
outputCCBAODES
# Out:
# Global evidence:
# log(Z)    -1671.530892 +/-  0.254313
#
# Local evidences:
# log(Z_1)    -1677.910303 +/-  0.391947
# log(Z_2)    -1673.039280 +/-  0.257123
# log(Z_3)    -1674.011698 +/-  0.262343
# log(Z_4)    -1671.897903 +/-  0.255166
#
# Run-time information:
# ncluster           4
# nposterior      2837
# nequals          336
# ndead           2837
# nlive              0
# nlike         184740
# <nlike>        [0.0]
#
# Parameter estimates:
# H0            H_{0}                6.839E+01 +/- 2.662E+00
# Om            \Omega_{m0}          3.056E-01 +/- 5.001E-03
# rd            r_d (Mpc)            1.478E+02 +/- 5.816E+00
# L             L                    1.662E+03 +/- 1.135E+00
# Ldof          L/Dof                9.007E-01 +/- 6.154E-04
# p             p                    9.991E-01 +/- 6.663E-05
# Omega_Lambda  \Omega_{\Lambda0}    6.944E-01 +/- 5.001E-03
