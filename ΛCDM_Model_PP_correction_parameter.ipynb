# %%
from numpy import pi, log, sqrt 
import getdist
import numpy as np
from io import StringIO
from getdist import plots, MCSamples
import random
from scipy.integrate import quad
from scipy.interpolate import interp1d
from scipy.integrate import odeint
import scipy.integrate as integrate
import matplotlib.pyplot as plt
from scipy import stats
import pypolychord
from pypolychord.settings import PolyChordSettings
from pypolychord.priors import UniformPrior, GaussianPrior
import scipy.optimize as op
from numpy.linalg import inv
from mpi4py import MPI
import sympy as sp
import scipy.linalg as la
import pandas as pd

# %% [markdown]
# # Cosmic Chronometers Dataset with Full Covariance
#
# **Source:** [https://gitlab.com/mmoresco/CCcovariance](https://gitlab.com/mmoresco/CCcovariance)
#
# ### Description
#
# This analysis utilizes the Cosmic Chronometers (CC) dataset with the full covariance matrix and prepares the likelihood function for cosmological parameter estimation.
#
# ### Citation Guidelines
#
# If you use this dataset, please cite the following foundational works by Prof. Dr. Moresco:
#
# - Moresco et al. (2016), [arXiv:1804.05864](https://doi.org/10.48550/arXiv.1804.05864)
# - Moresco (2020), [arXiv:2003.07362](https://doi.org/10.48550/arXiv.2003.07362)
#
# Additionally, when using the same data, please acknowledge these important references:
#
# - Simon et al. (2005), [arXiv:1201.3609](https://doi.org/10.48550/arXiv.1201.3609)
# - Stern et al. (2010), [arXiv:1503.01116](https://doi.org/10.48550/arXiv.1503.01116)
# - Moresco et al. (2012), [arXiv:1601.01701](https://doi.org/10.48550/arXiv.1601.01701)

# %%
#Load CC dataset and Build Full Covariance Matrix
filename = 'datasets/Hubble_data/HzTable_MM_BC03.dat'
z, Hz, errHz = np.genfromtxt(filename, comments='#', usecols=(0,1,2), unpack=True, delimiter=',')
ref = np.genfromtxt(filename, comments='#', usecols=(3), unpack=True, dtype=str, delimiter=',')

filename = 'datasets/Hubble_data/data_MM20.dat'
zmod, imf, slib, sps, spsooo = np.genfromtxt(filename, comments='#', usecols=(0,1,2,3,4), unpack=True)

cov_mat_diag = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	cov_mat_diag[i,i] = errHz[i]**2

imf_intp = np.interp(z, zmod, imf)/100
slib_intp = np.interp(z, zmod, slib)/100
sps_intp = np.interp(z, zmod, sps)/100
spsooo_intp = np.interp(z, zmod, spsooo)/100

cov_mat_imf = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_slib = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_sps = np.zeros((len(z), len(z)), dtype='float64')
cov_mat_spsooo = np.zeros((len(z), len(z)), dtype='float64')

for i in range(len(z)):
	for j in range(len(z)):
		cov_mat_imf[i,j] = Hz[i] * imf_intp[i] * Hz[j] * imf_intp[j]
		cov_mat_slib[i,j] = Hz[i] * slib_intp[i] * Hz[j] * slib_intp[j]
		cov_mat_sps[i,j] = Hz[i] * sps_intp[i] * Hz[j] * sps_intp[j]
		cov_mat_spsooo[i,j] = Hz[i] * spsooo_intp[i] * Hz[j] * spsooo_intp[j]

cov_mat = cov_mat_diag + cov_mat_spsooo + cov_mat_imf
inv_cov_mat = inv(cov_mat)

cov_mat_cc = inv_cov_mat

# %% [markdown]
# # PantheonPlus Dataset (CosmoSIS Likelihood)
#
# **Source Link:** [Pantheon+ CosmoSIS Likelihood Script](https://github.com/PantheonPlusSH0ES/DataRelease/blob/main/Pantheon%2B_Data/5_COSMOLOGY/cosmosis_likelihoods/Pantheon%2B_only_cosmosis_likelihood.py)
# **Dataset Link:** [Pantheon+ Distances and Covariance](https://github.com/PantheonPlusSH0ES/DataRelease/tree/main/Pantheon%2B_Data/4_DISTANCES_AND_COVAR)
#
# ### Description
#
# This analysis utilizes the full **STAT+SYS** covariance matrix provided in the PantheonPlus data release to construct a supernova likelihood. The approach follows the CosmoSIS likelihood format and incorporates both statistical and systematic uncertainties in the SN Ia light curves.
#
# ### Citation Guidelines
#
# If you use this dataset or the associated likelihood script in your research, please cite the following key works:
#
# - **Pantheon+ Compilation and Analysis Methodology:**
#   - Brout et al. (2022), [arXiv:2112.03863](https://doi.org/10.48550/arXiv.2112.03863)
#   - Scolnic et al. (2022), [arXiv:2202.04077](https://doi.org/10.48550/arXiv.2202.04077)
#
# - **Covariance Matrix Construction:**
#   - Conley et al. (2011), [arXiv:1104.1443](https://doi.org/10.48550/arXiv.1104.1443)

# %%
#Load Pantheonplus dataset and Build the Covariance Matrix
values_filename = 'datasets/sn_data/PantheonPlus/Pantheon+SH0ES.dat'
cov_filename = 'datasets/sn_data/PantheonPlus/Pantheon+SH0ES_STAT+SYS.cov'

data = pd.read_csv(values_filename, sep=r'\s+')
origlen = len(data)
ww = (data['zHD'] > 0.01)  # Filter condition for zHD > 0.01
zcmb = data['zHD'][ww].values  # vpec corrected redshift (zCMB)
zhelio = data['zHEL'][ww].values  # Heliocentric redshift

# -------------------------
# RAW SALT2 VARIABLES 
# -------------------------
mB   = data['mB'][ww].values
x1   = data['x1'][ww].values
c_sn = data['c'][ww].values
host_mass = data['HOST_LOGMASS'][ww].values

#mag = data['m_b_corr'][ww].values  # Corrected magnitudes
N = len(mB)

filename = cov_filename
#print("Loading covariance from {}".format(filename))
f = open(filename)
line = f.readline()
n = int(len(zcmb))
C = np.zeros((n,n))
ii = -1
jj = -1
mine = 999
maxe = -999
for i in range(origlen):
    jj = -1
    if ww[i]:
        ii += 1
    for j in range(origlen):
        if ww[j]:
            jj += 1
        val = float(f.readline())
        if ww[i]:
            if ww[j]:
                C[ii,jj] = val

f.close()
#print('Done')
cov = C
xdiag = 1/cov.diagonal()  # diagonal before marginalising constant
zmin = zcmb.min()
zmax = zcmb.max()
zmaxi = 1.1 ## we interpolate to 1.1 beyond that exact calc
print("Pantheon SN: zmin=%f zmax=%f N=%i" % (zmin, zmax, N))
ninterp=150
zinter = np.linspace(1e-3, zmaxi, ninterp)
icov = la.inv(cov)
# Out:
# Pantheon SN: zmin=0.010160 zmax=2.261370 N=1590

# %% [markdown]
# # DESI DR2 Dataset with Full Covariance
#
# **Source of Dataset:**
# [DESI BAO Data - GitHub (CobayaSampler)](https://github.com/CobayaSampler/bao_data)
#
# ### Description
#
# This analysis utilizes incorporates the **DESI Data Release 2 (DR2)** dataset, which includes baryon acoustic oscillation (BAO) measurements derived from over 14 million galaxies and quasars. The full covariance matrix is used in the likelihood analysis to properly account for measurement uncertainties and correlations between data points.
#
# The dataset is made publicly available and formatted for direct use in cosmological inference frameworks such as [Cobaya](https://cobaya.readthedocs.io/) and [CosmoMC](https://cosmologist.info/cosmomc/).
#
# ### Citation Guidelines
#
# If you use this dataset in your work, please cite the following:
#
# - **DESI Collaboration (2025)** : _DESI DR2 Results II: Measurements of Baryon Acoustic Oscillations and Cosmological Constraints_ [arXiv:2503.14738] : (https://doi.org/10.48550/arXiv.2503.14738)

# %%
#loading BAO dataset with Covarinace matrix
dirBD= "datasets/DESI_DR2_data/desi_gaussian_bao_ALL_GCcomb_mean.txt"
BaoData = np.genfromtxt(dirBD)
xarr = np.array(BaoData[:,0])
yarr = np.array(BaoData[:,1])

funarr = np.genfromtxt(dirBD,dtype='str')[:,2]
print(funarr)

def modelArr(name):
    mod = []

    for j in range(len(funarr)):
        if (funarr[j] == name):
             mod.append([xarr[j],yarr[j]])
    mod = np.array(mod)
    mod = mod[np.argsort(mod[:,0])]
    return mod

cov_bao = np.loadtxt("datasets/DESI_DR2_data/desi_gaussian_bao_ALL_GCcomb_cov.txt")  
cov_bao_inv = np.linalg.inv(cov_bao)
# Out:
# ['DVrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd' 'DHrd' 'DMrd'
#  'DHrd' 'DHrd' 'DMrd']

# %% [markdown]
# 1. **Define the normalized Hubble function** $E(\theta, z)$:
#
# $$
# E(z) = \sqrt{\Omega_m (1 + z)^3 + (1 - \Omega_m)}
# $$
#
# 2. **The Hubble function** $H(\theta, z)$:
#
# $$
# H(z) = H_0 \times E(z)
# $$

# %%
#H functions
c = 299792.458

def E(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    OL = 1 - Om
    return np.sqrt(Om*(1+z)**3 + OL)

def H(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(H0*E(theta,z[j]))
    arr = np.array(arr)
    return arr

H([67,0.32,-19,-0.07,0.12,2.56,147],[1,2,3])
# Out:
# array([120.6      , 204.5421228, 308.2      ])

# %% [markdown]
# 3. The comoving distance function $D_H(\theta, z)$:
#
# $$
# D_H(z) = \frac{c}{H(z)}
# $$
#
# 4. The comoving distance scaled by the sound horizon:
#
# $$
# \frac{D_H(z)}{r_d} = \frac{c}{H(z) \times r_d}
# $$

# %%
#DH functions
def DH(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    arr = []
    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])))
    arr = np.array(arr)
    return arr

def DHrd(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    arr = []

    for j in range(len(z)):
        arr.append(c/(H0*E(theta,z[j])*rd))
    arr = np.array(arr)
    return arr

DHrd([67,0.32,-19,-0.07,0.12,2.56,147],[1,2,3])
# Out:
# array([16.91048488,  9.97058429,  6.61714626])

# %% [markdown]
# The Sk function $S_k(\theta, x)$:
#
# $$
# S_k(x) =
# \begin{cases}
# \frac{\sin\left(\sqrt{-\Omega_k} \, x\right)}{\sqrt{-\Omega_k}} & \text{if } \Omega_k < -10^{-15} \\
# \frac{\sinh\left(\sqrt{\Omega_k} \, x\right)}{\sqrt{\Omega_k}} & \text{if } \Omega_k > 10^{-15} \\
# x & \text{if } \Omega_k = 0
# \end{cases}
# $$
#
# Where:
#
# * $\Omega_k$ is the curvature parameter (based on the `Ok` variable in your function).
# * $x$ is the input variable in the function.
#
# This function evaluates different cases based on the sign and magnitude of $\Omega_k$ (denoted as `Ok`), using either the sine or hyperbolic sine functions, or returning $x$ when $\Omega_k = 0$.

# %%
def Sk(theta,x):
    H0, Om, M, dM, alpha, beta, rd = theta
    Ok =0
    if Ok < -10**(-15):
        return np.sin(np.sqrt(-Ok)*x)/np.sqrt(-Ok)
    #if Ok == 0:
    #    return x
    elif Ok > 10**(-15):
        return np.sinh(np.sqrt(Ok)*x)/np.sqrt(Ok)
    else:
        return x

# %% [markdown]
# **Derivative of $\chi$ with respect to $z$** :
#
# $$
# \frac{d\chi}{dz} = \frac{1}{E(\theta, z)}
# $$
#
# **Integral of $\chi$** :
#
# $$
# \chi(z) = \int_0^z \frac{dz'}{E(\theta, z')}
# $$

# %%
# function that returns dDC/dz,df/dz
def dchidz(x, z, H0, Om, M, dM, alpha, beta, rd):
    return 1/E([H0, Om, M, dM, alpha, beta, rd],z)

def chiInt(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    z = np.hstack((np.array((0)), z))
    arr = odeint(dchidz,0,z,args=(H0, Om, M, dM, alpha, beta, rd,))
    return np.delete(arr ,0)

chiInt([67,0.32,-19,-0.07,0.12,2.56,147],[1,2,3])
# Out:
# array([0.7624812 , 1.18936468, 1.45585048])

# %% [markdown]
# 5. The comoving angular diameter distance is computed as: $D_M(\theta, z)$:
#
# $$
# D_M(z) = \frac{c}{H_0} \cdot S_k\left( \chi(z) \right)
# $$
#
# * $\chi(z) = \int_0^z \frac{c}{H(z')} \, dz'$ is the comoving radial distance
# * $S_k(\chi)$ accounts for spatial curvature:
#
# $$
# S_k(\chi) =
# \begin{cases}
# \frac{1}{\sqrt{\Omega_k}} \sinh\left(\sqrt{\Omega_k} \chi\right) & \text{if } \Omega_k > 0 \ (\text{open}) \\
# \chi & \text{if } \Omega_k = 0 \ (\text{flat}) \\
# \frac{1}{\sqrt{|\Omega_k|}} \sin\left(\sqrt{|\Omega_k|} \chi\right) & \text{if } \Omega_k < 0 \ (\text{closed})
# \end{cases}
# $$
#
# 6. The comoving angular diameter distance scaled by the sound horizon:
#
#
# $$
# \frac{D_M(z)}{r_d} = \frac{c}{H_0 \cdot r_d} \cdot S_k\left( \chi(z) \right)
# $$

# %%
#DM

def DM(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/H0)
    arr = np.array(arr)
    arr.shape
    return arr

def DMrd(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    chi = chiInt(theta,z)

    arr = []

    for i in range(len(z)):
        arr.append(c*Sk(theta,chi[i])/(H0*rd))
    arr = np.array(arr)
    arr.shape
    return arr

DMrd([67,0.32,-19,-0.07,0.12,2.56,147],[1,2,3])
# Out:
# array([23.20906838, 36.20292027, 44.31444763])

# %% [markdown]
# 7. The volume-averaged distance combines radial and transverse distances and is defined as:
#
# $$
# D_V(z) = \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3}
# $$
#
# * $D_H(z) = \dfrac{c}{H(z)}$: the comoving Hubble distance
# * $D_M(z)$: the comoving angular diameter distance
# * This is often used when the BAO measurement is spherically averaged.
#
# 8. The volume-averaged diameter distance scaled by the sound horizon:
#
# $$
# \frac{D_V(z)}{r_d} = \frac{ \left[ z \cdot D_H(z) \cdot D_M(z)^2 \right]^{1/3} }{r_d}
# $$

# %%
#DV

def DV(theta,z):
    H0, Om, M, dM, alpha, beta, rd = theta
    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2))
    arr = np.array(arr)
    arr.shape
    return arr

def DVrd(theta,z):

    H0, Om, M, dM, alpha, beta, rd = theta
    dh = DH(theta,z)
    dm = DM(theta,z)
    arr = []

    for i in range(len(z)):
        arr.append(np.cbrt(z[i]*dh[i]*dm[i]**2)/rd)
    arr = np.array(arr)
    arr.shape
    return arr

DVrd([67,0.32,-19,-0.07,0.12,2.56,147],[1,2,3])
# Out:
# array([20.88448766, 29.67649485, 33.90737919])

# %% [markdown]
# ### Luminosity Distance
#
# $$
# D_L(z) = (1 + z_{\mathrm{hel}})\,\frac{c}{H_0} \int_0^{z_{\mathrm{cmb}}} \frac{dz'}{E(z')}
# $$
#
# where:
# - $z_{\mathrm{cmb}}$ is the CMB-frame redshift
# - $z_{\mathrm{hel}}$ is the heliocentric redshift
# - $E(z) = H(z)/H_0$
#
# ### Distance Modulus
#
# $$
# \mu(z) = 5 \log_{10} \left( D_L(z) \right) + 25
# $$
#
# ### Host Mass Step Correction
#
# The absolute magnitude depends on host galaxy mass:
#
# $$
# M_B =
# \begin{cases}
# M, & M_{\mathrm{host}} < 10^{10} M_\odot \\
# M + \Delta_M, & \text{otherwise}
# \end{cases}
# $$
#
# ### Full Supernova Model (Light-Curve Calibration)
#
# The predicted apparent magnitude is:
#
# $$
# m_{\mathrm{model}} =
# \mu(z)
# +
# M_B
# -
# \alpha X_1
# +
# \beta C
# $$
#
# where:
# - $X_1$ is the stretch parameter
# - $C$ is the color parameter
# - $\alpha$, $\beta$ are nuisance parameters

# %%
def DL(theta, zcmb, zhel):
    H0, Om, M, dM, alpha, beta, rd = theta
    chi = chiInt(theta, zcmb)
    return (1+zhel)*c*chi/H0  

def M_step(theta, host_mass):
    H0, Om, M, dM, alpha, beta, rd = theta
    out = np.full_like(host_mass, M)
    mask = host_mass >= 10.0
    out[mask] = M + dM
    return out

def m_model(theta, zcmb, zhel, x1, c_sn, host_mass):
    H0, Om, M, dM, alpha, beta, rd = theta

    dL = DL(theta, zcmb, zhel)
    mu = 5*np.log10(dL) + 25
    MB = M_step(theta, host_mass)

    return mu + MB - alpha*x1 + beta*c_sn

# %%
def Omega_Lambda(theta):
    H0, Om, M, dM, alpha, beta, rd = theta
    OL = 1 - Om
    return OL

# %% [markdown]
# ### Log Likelihood Function for Cosmic Chronometer Measurements
#
# Given a model prediction $H(z; \theta)$, observed data $H_z$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2 = \left( H(z; \theta) - H_z \right)^T \cdot \mathbf{C}^{-1} \cdot \left( H(z; \theta) - H_z \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2
# $$
#
#
# ### Output Statistics
#
# The function also returns:
#
# * Minimum chi-squared: $\chi^2_{\text{min}}$
# * Total number of data points: $N$
# * Reduced chi-squared:
#
# $$
# \chi^2_{\text{red}} = \frac{\chi^2}{N - k}
# $$
#
# * $p$-value:
#
# $$
# p = 1 - F_{\chi^2}(\chi^2; \, \text{dof} = N - k)
# $$
#
# * Derived Cosmological Parameters:
#
# $$
# \Omega_\Lambda = 1 - \Omega_m \quad (\text{In the case Dark Energy Density })
# $$

# %%
def lnlike(theta,model,z,Hz,cov_mat_cc):
    prediction = model(theta,z)
    residualcc = prediction - Hz
    chi2 = residualcc.T @ cov_mat_cc @ residualcc
    return chi2

def lnlikeCC(theta):
    chi = 0; i = 0
    chi += lnlike(theta, H, z, Hz, cov_mat_cc)
    i += len(z)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1-stats.chi2.cdf(x=chi, df=(i-len(theta))), OL]

print(lnlikeCC([67,0.32,-19,-0.07,0.12,2.56,147]))
# Out:
# (np.float64(-6.183367402883178), [np.float64(6.183367402883178), np.float64(0.7729209253603972), np.float64(0.6267003512617542), 0.6799999999999999])

# %% [markdown]
# ### Log Likelihood Function for BAO Dataset with Full Covariance
#
# Given model predictions $\hat{y}_i = f_i(z_i; \theta)$ (e.g., BAO observables like $D_H$, $D_V$, and $D_A$, etc.), observed data $y_i$, and the inverse covariance matrix $\mathbf{C}^{-1}$, the chi-squared statistic is computed as:
#
# $$
# \chi^2(\theta) = \left( \hat{y}(\theta) - y \right)^T \cdot \mathbf{C}^{-1} \cdot \left( \hat{y}(\theta) - y \right)
# $$
#
# The corresponding log-likelihood is:
#
# $$
# \ln \mathcal{L}(\theta) = -\frac{1}{2} \chi^2(\theta)
# $$

# %%
# likelihood with covariance matrix
def lnlikecov(theta, model, x, y, cov):
    prediction = []

    for i in range(len(model)):
        fun = model[i]
        prediction.append(eval(fun)(theta, [x[i]]))
    prediction = np.array(prediction)[:, 0]
    vec = (prediction - y)
    result = np.dot(np.dot(vec, cov), vec.T)
    return result

print(lnlikecov([67,0.32,-19,-0.07,0.12,2.56,147], funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv))
# Out:
# 40.55527665589413

# %% [markdown]
# This function computes the log-likelihood of BAO data given cosmological parameters $\theta$. It calculates the chi-squared statistic comparing model predictions to observations using the inverse covariance matrix, then returns the negative chi-squared (log-likelihood), reduced chi-squared, p-value, and the derived parameter $\Omega_\Lambda$, providing a measure of fit quality and model consistency with the data.

# %%
def lnlikeBAO(theta):
    x = np.array(BaoData[:, 0])
    y = np.array(BaoData[:, 1])

    # Use your manually loaded inverse covariance matrix
    chi = lnlikecov(theta, funarr, x, y, cov_bao_inv)
    i = len(x)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1-stats.chi2.cdf(x=chi, df=(i-len(theta))), OL]

lnlikeBAO([67,0.32,-19,-0.07,0.12,2.56,147])
# Out:
# (np.float64(-40.55527665589413),
#  [np.float64(40.55527665589413),
#   np.float64(6.7592127759823555),
#   np.float64(3.542489912522484e-07),
#   0.6799999999999999])

# %% [markdown]
# ### Residuals
#
# $$
# \Delta = m_{\mathrm{obs}} - m_{\mathrm{model}}
# $$
#
# ### Chi-Squared (Full Covariance)
#
# $$
# \chi^2 = \Delta^T C^{-1} \Delta
# $$
#
# ### Log-Likelihood
#
# $$
# \ln \mathcal{L} = -\frac{1}{2} \chi^2
# $$

# %%
def A(theta, zcmb, mB_obs, inverse_covar):
    model = m_model(theta, zcmb, zhelio, x1, c_sn, host_mass)
    residual = mB_obs - model
    chi2 = residual.T @ inverse_covar @ residual
    return chi2

def lnlikePPCor(theta):
    chi = A(theta, zcmb, mB, icov)
    i = len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1-stats.chi2.cdf(x=chi, df=(i-len(theta))), OL]

print(lnlikePPCor([67,0.32,-19,-0.07,0.12,2.56,147]))
# Out:
# (np.float64(-11683.299807110561), [np.float64(11683.299807110561), np.float64(7.380479979223349), np.float64(0.0), 0.6799999999999999])

# %% [markdown]
# $\mathcal{L}_{\text{CC + BAO + PP}} = \mathcal{L}_{\text{CC}} \times \mathcal{L}_{\text{BAO}} \times \mathcal{L}_{\text{PP}},$

# %%
def lnlikeCCBAOPPCor(theta):

    chi = lnlikecov(theta, funarr, np.array(BaoData[:, 0]), np.array(BaoData[:, 1]), cov_bao_inv)
    i = len(BaoData[:, 0])
    chi += lnlike(theta, H, z, Hz, cov_mat_cc); i += len(z)
    chi += A(theta, zcmb, mB, icov);i += len(zcmb)
    OL = Omega_Lambda(theta)
    return -chi, [chi, chi/(i-len(theta)), 1-stats.chi2.cdf(x=chi, df=(i-len(theta))), OL]

print(lnlikeCCBAOPPCor([67,0.32,-19,-0.07,0.12,2.56,147]))
# Out:
# (np.float64(-11730.03845116934), [np.float64(11730.03845116934), np.float64(7.2812156742205705), np.float64(0.0), 0.6799999999999999])

# %%
runs = 350

# %%
def dumper(live, dead, logweights, logZ, logZerr):
    print("Last dead point:", dead[-1])

# %%
def uniprior(hypercube):
    prior = []
    prior.append(UniformPrior(50.0,100.0)(hypercube[0]))
    prior.append(UniformPrior(0.0,1.0)(hypercube[1]))
    prior.append(UniformPrior(-20.0,-18.0)(hypercube[2]))
    prior.append(UniformPrior(-1.0,1.0)(hypercube[3]))
    prior.append(UniformPrior(0.0,1.0)(hypercube[4]))
    prior.append(UniformPrior(0.0,5.0)(hypercube[5]))
    prior.append(UniformPrior(100.0,200.0)(hypercube[6]))
    return prior

# %%
settingsCCBAOPPCor = PolyChordSettings(7,4)
settingsCCBAOPPCor.file_root = 'CC + DESI DR2 + PP'
settingsCCBAOPPCor.nlive = runs
settingsCCBAOPPCor.do_clustering = True
settingsCCBAOPPCor.read_resume = False

# %%
outputCCBAOPPCor = pypolychord.run_polychord(lnlikeCCBAOPPCor, 7, 4, settingsCCBAOPPCor, uniprior, dumper)
# Out:
# PolyChord: MPI is already initilised, not initialising, and will not finalize
#
# PolyChord: Next Generation Nested Sampling
# copyright: Will Handley, Mike Hobson & Anthony Lasenby
#   version: 1.22.3
#   release: 22nd Nov 2025
#     email: wh260@mrao.cam.ac.uk
#
# Run Settings
# nlive    :     350
# nDims    :       7
# nDerived :       4
# Doing Clustering
# Synchronous parallelisation
# Generating equally weighted posteriors
# Generating weighted posteriors
# Clustering on posteriors
# Writing a resume file to chains/CC + DESI DR2 + PP.resume
#
# generating live points
#
#
# all live points generated
#
# Speed  1 =  0.114E-02 seconds
# number of repeats:           35
# started sampling
#
# Last dead point: [ 5.72544062e+01  7.71371600e-01 -1.97395670e+01 -7.03253893e-01
#   8.27792214e-01  1.45837121e+00  1.25555407e+02  4.70269181e+04
#   2.91911348e+01  0.00000000e+00  2.28628400e-01 -6.25525726e+04
#  -4.70269181e+04]
# _________________
# lives      | 350 |
# phantoms   |7522 |
# posteriors | 351 |
# equals     |   1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 351
# nposterior =                 351
# nequals    =                   1
# nlike      =               17725
# <nlike>    =          49.64   (           1.42 per slice )
# log(Z)     =       -47034.12 +/-  0.83
# log(Z_1)   =       -47034.12 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 7.82684586e+01  7.67220703e-01 -1.89768868e+01  7.81022861e-01
#   2.05719710e-01  4.15115667e+00  1.15006190e+02  2.52593595e+04
#   1.56793045e+01  0.00000000e+00  2.32779297e-01 -2.71541493e+04
#  -2.52593595e+04]
# __________________
# lives      |  350 |
# phantoms   |10865 |
# posteriors |  702 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                 702
# nposterior =                 702
# nequals    =                   1
# nlike      =               48149
# <nlike>    =          86.93   (           2.48 per slice )
# log(Z)     =       -25267.57 +/-  0.83
# log(Z_1)   =       -25267.57 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 8.79940413e+01  6.29083503e-01 -1.86165037e+01 -1.69256393e-01
#   4.77201436e-01  3.89050754e+00  1.20927394e+02  1.53030409e+04
#   9.49909426e+00  0.00000000e+00  3.70916497e-01 -1.61524283e+04
#  -1.53030409e+04]
# __________________
# lives      |  350 |
# phantoms   |11715 |
# posteriors | 1053 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1053
# nposterior =                1053
# nequals    =                   1
# nlike      =               80678
# <nlike>    =          92.94   (           2.66 per slice )
# log(Z)     =       -15312.25 +/-  0.84
# log(Z_1)   =       -15312.25 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 6.82303270e+01  4.47560914e-01 -1.94567355e+01  5.64911258e-01
#   3.86537850e-02  3.29010866e+00  1.52122474e+02  9.84743283e+03
#   6.11262125e+00  0.00000000e+00  5.52439086e-01 -1.40736559e+04
#  -9.84743283e+03]
# __________________
# lives      |  350 |
# phantoms   |11737 |
# posteriors | 1404 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1404
# nposterior =                1404
# nequals    =                   1
# nlike      =              115850
# <nlike>    =         100.49   (           2.87 per slice )
# log(Z)     =        -9857.65 +/-  0.84
# log(Z_1)   =        -9857.65 +/-  0.84 (still evaluating)
#
#
#
# Last dead point: [ 5.87951119e+01  6.82974373e-01 -1.96477968e+01  1.12591981e-02
#   3.59019170e-01  9.69139010e-01  1.35226988e+02  6.56707094e+03
#   4.07639413e+00  0.00000000e+00  3.17025627e-01 -1.12916054e+04
#  -6.56707094e+03]
# __________________
# lives      |  350 |
# phantoms   |11151 |
# posteriors | 1755 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                1755
# nposterior =                1755
# nequals    =                   1
# nlike      =              153269
# <nlike>    =         106.91   (           3.05 per slice )
# log(Z)     =        -6578.25 +/-  0.83
# log(Z_1)   =        -6578.25 +/-  0.83 (still evaluating)
#
#
#
# Last dead point: [ 7.17616080e+01  3.59935267e-01 -1.95177296e+01  1.80341137e-02
#   2.16893584e-01  4.77966388e-01  1.36019353e+02  4.87709797e+03
#   3.02737304e+00  0.00000000e+00  6.40064733e-01 -1.85871440e+04
#  -4.87709797e+03]
# __________________
# lives      |  350 |
# phantoms   |11678 |
# posteriors | 2106 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2106
# nposterior =                2106
# nequals    =                   1
# nlike      =              193052
# <nlike>    =         113.67   (           3.25 per slice )
# log(Z)     =        -4889.11 +/-  0.76
# log(Z_1)   =        -4889.11 +/-  0.76 (still evaluating)
#
#
#
# Last dead point: [ 6.61041061e+01  2.98052259e-01 -1.93570098e+01  4.10043915e-02
#   2.49412782e-01  4.55681531e+00  1.59730449e+02  3.79213361e+03
#   2.35390044e+00  0.00000000e+00  7.01947741e-01 -4.77440765e+03
#  -3.79213361e+03]
# __________________
# lives      |  350 |
# phantoms   |11578 |
# posteriors | 2457 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2457
# nposterior =                2457
# nequals    =                   2
# nlike      =              235034
# <nlike>    =         119.95   (           3.43 per slice )
# log(Z)     =        -3804.60 +/-  0.64
# log(Z_1)   =        -3804.60 +/-  0.64 (still evaluating)
#
#
#
# Last dead point: [ 8.28300432e+01  5.30288233e-01 -1.87717062e+01  2.40598986e-03
#   1.47107768e-01  4.22458984e+00  1.09254430e+02  3.11738377e+03
#   1.93506131e+00  0.00000000e+00  4.69711767e-01 -4.89834351e+03
#  -3.11738377e+03]
# __________________
# lives      |  350 |
# phantoms   |11752 |
# posteriors | 2808 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                2808
# nposterior =                2808
# nequals    =                   2
# nlike      =              279938
# <nlike>    =         128.30   (           3.67 per slice )
# log(Z)     =        -3130.87 +/-  0.59
# log(Z_1)   =        -3130.87 +/-  0.59 (still evaluating)
#
#
#
# Last dead point: [ 7.12898056e+01  2.84002110e-01 -1.93176889e+01  9.76995047e-02
#   1.56243879e-01  2.06441997e+00  1.55002288e+02  2.66397717e+03
#   1.65361711e+00  0.00000000e+00  7.15997890e-01 -2.84393407e+03
#  -2.66397717e+03]
# __________________
# lives      |  350 |
# phantoms   |11844 |
# posteriors | 3159 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3159
# nposterior =                3159
# nequals    =                   2
# nlike      =              327379
# <nlike>    =         135.55   (           3.87 per slice )
# log(Z)     =        -2678.15 +/-  0.52
# log(Z_1)   =        -2678.15 +/-  0.52 (still evaluating)
#
#
#
# Last dead point: [ 6.88779258e+01  2.08354878e-01 -1.93597035e+01 -1.39877943e-01
#   1.30416311e-01  1.91575835e+00  1.51468311e+02  2.35445505e+03
#   1.46148668e+00  0.00000000e+00  7.91645122e-01 -2.75555625e+03
#  -2.35445505e+03]
# __________________
# lives      |  350 |
# phantoms   |12034 |
# posteriors | 3510 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3510
# nposterior =                3510
# nequals    =                   2
# nlike      =              376351
# <nlike>    =         139.92   (           4.00 per slice )
# log(Z)     =        -2370.14 +/-  0.66
# log(Z_1)   =        -2370.14 +/-  0.66 (still evaluating)
#
#
#
# Last dead point: [ 8.47326452e+01  4.04187571e-01 -1.89963298e+01  1.30134766e-01
#   8.99504208e-02  2.54422414e+00  1.09311195e+02  2.11782489e+03
#   1.31460266e+00  2.22044605e-16  5.95812429e-01 -2.28498748e+03
#  -2.11782489e+03]
# __________________
# lives      |  350 |
# phantoms   |12038 |
# posteriors | 3861 |
# equals     |    1 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                3861
# nposterior =                3861
# nequals    =                   2
# nlike      =              427197
# <nlike>    =         145.27   (           4.15 per slice )
# log(Z)     =        -2134.12 +/-  0.59
# log(Z_1)   =        -2134.12 +/-  0.59 (still evaluating)
#
#
#
# Last dead point: [ 7.25946022e+01  3.04872903e-01 -1.92820022e+01  6.96898715e-02
#   1.72197913e-01  2.30271332e+00  1.34744750e+02  1.94845695e+03
#   1.20947048e+00  1.16285276e-08  6.95127097e-01 -1.99104084e+03
#  -1.94845695e+03]
# __________________
# lives      |  350 |
# phantoms   |11953 |
# posteriors | 4212 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4212
# nposterior =                4212
# nequals    =                   4
# nlike      =              478783
# <nlike>    =         147.39   (           4.21 per slice )
# log(Z)     =        -1965.08 +/-  0.45
# log(Z_1)   =        -1965.08 +/-  0.45 (still evaluating)
#
#
#
# Last dead point: [ 6.44798419e+01  3.20160223e-01 -1.94412837e+01 -3.40947882e-02
#   8.13648193e-02  3.19331120e+00  1.54122249e+02  1.83520484e+03
#   1.13917122e+00  7.47746639e-05  6.79839777e-01 -1.86349320e+03
#  -1.83520484e+03]
# __________________
# lives      |  350 |
# phantoms   |12795 |
# posteriors | 4563 |
# equals     |    4 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4563
# nposterior =                4563
# nequals    =                   2
# nlike      =              531001
# <nlike>    =         149.19   (           4.26 per slice )
# log(Z)     =        -1852.78 +/-  0.41
# log(Z_1)   =        -1852.78 +/-  0.41 (still evaluating)
#
#
#
# Last dead point: [ 7.25770130e+01  3.01935695e-01 -1.93128835e+01  7.53257437e-02
#   1.31321593e-01  1.61632684e+00  1.39685548e+02  1.74327922e+03
#   1.08211001e+00  1.12693089e-02  6.98064305e-01 -1.75788355e+03
#  -1.74327922e+03]
# __________________
# lives      |  350 |
# phantoms   |12039 |
# posteriors | 4914 |
# equals     |    7 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                4914
# nposterior =                4914
# nequals    =                   6
# nlike      =              584220
# <nlike>    =         152.05   (           4.34 per slice )
# log(Z)     =        -1761.74 +/-  0.40
# log(Z_1)   =        -1761.74 +/-  0.40 (still evaluating)
#
#
#
# Last dead point: [ 6.90418160e+01  3.38000356e-01 -1.93905143e+01  4.40884675e-02
#   1.34698057e-01  1.70457519e+00  1.43027293e+02  1.68190838e+03
#   1.04401513e+00  1.06926655e-01  6.61999644e-01 -1.71459417e+03
#  -1.68190838e+03]
# __________________
# lives      |  350 |
# phantoms   |12449 |
# posteriors | 5265 |
# equals     |   11 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5265
# nposterior =                5265
# nequals    =                   8
# nlike      =              638039
# <nlike>    =         153.77   (           4.39 per slice )
# log(Z)     =        -1700.49 +/-  0.30
# log(Z_1)   =        -1700.49 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 6.77217092e+01  2.87027233e-01 -1.93678091e+01 -3.80985482e-02
#   1.02102149e-01  2.93602043e+00  1.51232796e+02  1.63370668e+03
#   1.01409477e+00  3.40941205e-01  7.12972767e-01 -1.74080742e+03
#  -1.63370668e+03]
# __________________
# lives      |  350 |
# phantoms   |11693 |
# posteriors | 5616 |
# equals     |    2 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5616
# nposterior =                5616
# nequals    =                   5
# nlike      =              692814
# <nlike>    =         156.50   (           4.47 per slice )
# log(Z)     =        -1653.78 +/-  0.35
# log(Z_1)   =        -1653.78 +/-  0.35 (still evaluating)
#
#
#
# Last dead point: [ 6.62525096e+01  2.85407629e-01 -1.94332670e+01 -4.36192368e-02
#   1.20030034e-01  2.95985630e+00  1.55263550e+02  1.59961213e+03
#   9.92931180e-01  5.75088830e-01  7.14592371e-01 -1.61384397e+03
#  -1.59961213e+03]
# __________________
# lives      |  350 |
# phantoms   |11670 |
# posteriors | 5967 |
# equals     |   12 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                5967
# nposterior =                5967
# nequals    =                  17
# nlike      =              749528
# <nlike>    =         162.04   (           4.63 per slice )
# log(Z)     =        -1620.09 +/-  0.30
# log(Z_1)   =        -1620.09 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 6.44604424e+01  2.66533488e-01 -1.94609669e+01 -8.06973383e-02
#   1.44766608e-01  2.79746217e+00  1.60172438e+02  1.57514573e+03
#   9.77744089e-01  7.33894053e-01  7.33466512e-01 -1.58553832e+03
#  -1.57514573e+03]
# __________________
# lives      |  350 |
# phantoms   |11690 |
# posteriors | 6318 |
# equals     |   10 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6318
# nposterior =                6318
# nequals    =                  18
# nlike      =              807221
# <nlike>    =         164.84   (           4.71 per slice )
# log(Z)     =        -1596.45 +/-  0.29
# log(Z_1)   =        -1596.45 +/-  0.29 (still evaluating)
#
#
#
# Last dead point: [ 7.14327151e+01  2.67140163e-01 -1.92718911e+01 -5.72509327e-02
#   1.43630855e-01  2.20694408e+00  1.44993305e+02  1.55824852e+03
#   9.67255444e-01  8.23269861e-01  7.32859837e-01 -1.56547423e+03
#  -1.55824852e+03]
# __________________
# lives      |  350 |
# phantoms   |12192 |
# posteriors | 6669 |
# equals     |   21 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                6669
# nposterior =                6669
# nequals    =                  20
# nlike      =              865951
# <nlike>    =         167.80   (           4.79 per slice )
# log(Z)     =        -1580.04 +/-  0.27
# log(Z_1)   =        -1580.04 +/-  0.27 (still evaluating)
#
#
#
# Last dead point: [ 8.15014572e+01  2.82797182e-01 -1.90067825e+01 -1.15177406e-02
#   1.20483541e-01  2.43809094e+00  1.25401640e+02  1.54491502e+03
#   9.58978908e-01  8.78749615e-01  7.17202818e-01 -1.54645134e+03
#  -1.54491502e+03]
# __________________
# lives      |  350 |
# phantoms   |11753 |
# posteriors | 7020 |
# equals     |   33 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7020
# nposterior =                7020
# nequals    =                  35
# nlike      =              925788
# <nlike>    =         170.96   (           4.88 per slice )
# log(Z)     =        -1567.42 +/-  0.27
# log(Z_1)   =        -1567.42 +/-  0.27 (still evaluating)
#
#
#
# Last dead point: [ 6.52405305e+01  3.10572794e-01 -1.94686705e+01 -4.05345194e-02
#   1.22098505e-01  2.45285688e+00  1.55361939e+02  1.53491475e+03
#   9.52771416e-01  9.11543496e-01  6.89427206e-01 -1.56075681e+03
#  -1.53491475e+03]
# __________________
# lives      |  350 |
# phantoms   |11664 |
# posteriors | 7371 |
# equals     |   45 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7371
# nposterior =                7371
# nequals    =                  39
# nlike      =              985614
# <nlike>    =         170.93   (           4.88 per slice )
# log(Z)     =        -1558.00 +/-  0.26
# log(Z_1)   =        -1558.00 +/-  0.26 (still evaluating)
#
#
#
# Last dead point: [ 7.31926095e+01  3.13587532e-01 -1.92017217e+01 -5.55258541e-02
#   1.29290209e-01  2.44563013e+00  1.35916767e+02  1.52805429e+03
#   9.48512904e-01  9.29938908e-01  6.86412468e-01 -1.52994947e+03
#  -1.52805429e+03]
# __________________
# lives      |  350 |
# phantoms   |12005 |
# posteriors | 7722 |
# equals     |   74 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       1
# ndead      =                7722
# nposterior =                7722
# nequals    =                  62
# nlike      =             1046404
# <nlike>    =         173.69   (           4.96 per slice )
# log(Z)     =        -1551.80 +/-  0.26
# log(Z_1)   =        -1551.80 +/-  0.26 (still evaluating)
#
#
#
# Last dead point: [ 7.41243891e+01  3.04350190e-01 -1.91933970e+01 -1.25316210e-02
#   1.29374355e-01  2.58552326e+00  1.35856344e+02  1.52286533e+03
#   9.45291948e-01  9.41808966e-01  6.95649810e-01 -1.54924180e+03
#  -1.52286533e+03]
# _______________________
# lives      | 117 | 233 |
# phantoms   |4343 |8401 |
# posteriors |7861 |7934 |
# equals     |  39 |  62 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                8073
# nposterior =                8073
# nequals    =                  75
# nlike      =             1127280
# <nlike>    =         231.07   (           6.60 per slice )
# log(Z)     =        -1547.31 +/-  0.26
# log(Z_1)   =        -1547.84 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1548.20 +/-  0.28 (still evaluating)
#
#
#
# Last dead point: [ 5.97936028e+01  3.11707381e-01 -1.96485228e+01 -4.25035219e-02
#   1.38551961e-01  2.52622741e+00  1.66833815e+02  1.51894792e+03
#   9.42860288e-01  9.49690403e-01  6.88292619e-01 -1.52011652e+03
#  -1.51894792e+03]
# _______________________
# lives      | 108 | 242 |
# phantoms   |4174 |9222 |
# posteriors |7970 |8177 |
# equals     |  34 |  98 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                8425
# nposterior =                8425
# nequals    =                  98
# nlike      =             1209094
# <nlike>    =         233.75   (           6.68 per slice )
# log(Z)     =        -1544.08 +/-  0.26
# log(Z_1)   =        -1544.50 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1545.14 +/-  0.29 (still evaluating)
#
#
#
# Last dead point: [ 6.82476471e+01  3.05819687e-01 -1.93661933e+01 -3.73903133e-02
#   1.29261830e-01  2.53764904e+00  1.48683757e+02  1.51605768e+03
#   9.41066220e-01  9.54948175e-01  6.94180313e-01 -1.51630560e+03
#  -1.51605768e+03]
# _______________________
# lives      | 100 | 250 |
# phantoms   |4126 |9599 |
# posteriors |8082 |8415 |
# equals     |  56 | 118 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                8775
# nposterior =                8775
# nequals    =                 135
# nlike      =             1295640
# <nlike>    =         247.27   (           7.06 per slice )
# log(Z)     =        -1541.79 +/-  0.26
# log(Z_1)   =        -1542.28 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1542.75 +/-  0.29 (still evaluating)
#
#
#
# Last dead point: [ 6.26178292e+01  2.93157832e-01 -1.95636800e+01 -3.59313801e-02
#   1.41065929e-01  2.38819761e+00  1.62907437e+02  1.51386407e+03
#   9.39704577e-01  9.58639850e-01  7.06842168e-01 -1.51405668e+03
#  -1.51386407e+03]
# _______________________
# lives      |  94 | 256 |
# phantoms   |4333 |9979 |
# posteriors |8193 |8653 |
# equals     |  91 | 177 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                9124
# nposterior =                9124
# nequals    =                 255
# nlike      =             1380850
# <nlike>    =         243.46   (           6.96 per slice )
# log(Z)     =        -1540.15 +/-  0.27
# log(Z_1)   =        -1540.65 +/-  0.27 (still evaluating)
# log(Z_2)   =        -1541.09 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 7.23947588e+01  2.99996768e-01 -1.92515018e+01 -3.16570927e-02
#   1.38027179e-01  2.32784832e+00  1.40173478e+02  1.51208808e+03
#   9.38602163e-01  9.61448097e-01  7.00003232e-01 -1.51369047e+03
#  -1.51208808e+03]
# _________________________
# lives      |   91 |  259 |
# phantoms   | 3994 |10329 |
# posteriors | 8282 | 8918 |
# equals     |  104 |  270 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       2
# ndead      =                9478
# nposterior =                9478
# nequals    =                 305
# nlike      =             1468529
# <nlike>    =         250.51   (           7.16 per slice )
# log(Z)     =        -1539.04 +/-  0.27
# log(Z_1)   =        -1539.48 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1540.10 +/-  0.31 (still evaluating)
#
#
#
# Last dead point: [ 7.13434445e+01  3.02210909e-01 -1.92577697e+01 -5.13720973e-02
#   1.37205788e-01  2.47426324e+00  1.41771612e+02  1.51082002e+03
#   9.37815035e-01  9.63357799e-01  6.97789091e-01 -1.51237818e+03
#  -1.51082002e+03]
# ________________________________
# lives      |   75 |  269 |    6 |
# phantoms   | 3445 |10873 |  426 |
# posteriors | 8373 | 9158 | 8936 |
# equals     |  156 |  450 |  151 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =                9827
# nposterior =                9827
# nequals    =                 428
# nlike      =             1564687
# <nlike>    =         274.74   (           7.85 per slice )
# log(Z)     =        -1538.33 +/-  0.27
# log(Z_1)   =        -1538.83 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1539.41 +/-  0.31 (still evaluating)
# log(Z_3)   =        -1541.21 +/-  0.29 (still evaluating)
#
#
#
# Last dead point: [ 6.67135245e+01  3.10248490e-01 -1.94140606e+01 -3.29216296e-02
#   1.31618681e-01  2.44460397e+00  1.50578987e+02  1.50972017e+03
#   9.37132323e-01  9.64951673e-01  6.89751510e-01 -1.51146900e+03
#  -1.50972017e+03]
# ________________________________
# lives      |   71 |  278 |    1 |
# phantoms   | 3436 |10924 |  139 |
# posteriors | 8456 | 9414 | 8943 |
# equals     |  222 |  613 |   93 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       3
# ndead      =               10173
# nposterior =               10173
# nequals    =                 370
# nlike      =             1658733
# <nlike>    =         268.70   (           7.68 per slice )
# log(Z)     =        -1537.84 +/-  0.27
# log(Z_1)   =        -1538.32 +/-  0.28 (still evaluating)
# log(Z_2)   =        -1538.96 +/-  0.32 (still evaluating)
# log(Z_3)   =        -1540.86 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 7.10436265e+01  3.04712801e-01 -1.92768567e+01 -3.86865032e-02
#   1.40632622e-01  2.53533233e+00  1.42364012e+02  1.50888883e+03
#   9.36616282e-01  9.66118794e-01  6.95287199e-01 -1.51016435e+03
#  -1.50888883e+03]
# ________________________________
# lives      |   57 |  291 |    2 |
# phantoms   | 2582 |11208 |  101 |
# posteriors | 8525 | 9682 | 9420 |
# equals     |  278 |  851 |  618 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       3 /       4
# ndead      =               10520
# nposterior =               10520
# nequals    =                 460
# nlike      =             1753877
# <nlike>    =         271.84   (           7.77 per slice )
# log(Z)     =        -1537.53 +/-  0.28
# log(Z_1)   =        -1538.01 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.69 +/-  0.32 (still evaluating)
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1542.13 +/-  0.30 (still evaluating)
#
#
#
# Last dead point: [ 6.79311016e+01  3.01714323e-01 -1.93786086e+01 -4.24909640e-02
#   1.36430345e-01  2.41590700e+00  1.48652175e+02  1.50828260e+03
#   9.36239973e-01  9.66949834e-01  6.98285677e-01 -1.50834946e+03
#  -1.50828260e+03]
# _________________________
# lives      |   33 |  317 |
# phantoms   | 1664 |11300 |
# posteriors | 8584 | 9956 |
# equals     |  328 | 1034 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =               10855
# nposterior =               10855
# nequals    =                 565
# nlike      =             1827771
# <nlike>    =         211.13   (           6.03 per slice )
# log(Z)     =        -1537.35 +/-  0.28
# log(Z_1)   =        -1537.81 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.51 +/-  0.33 (still evaluating)
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.46101960e+01  3.06962041e-01 -1.94856628e+01 -3.51605630e-02
#   1.37280455e-01  2.44158967e+00  1.56143205e+02  1.50779539e+03
#   9.35937549e-01  9.67605629e-01  6.93037959e-01 -1.50847380e+03
#  -1.50779539e+03]
# _________________________
# lives      |   15 |  335 |
# phantoms   |  902 |11123 |
# posteriors | 8617 |10261 |
# equals     |  352 | 1160 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =               11193
# nposterior =               11193
# nequals    =                 625
# nlike      =             1899731
# <nlike>    =         205.60   (           5.87 per slice )
# log(Z)     =        -1537.25 +/-  0.28
# log(Z_1)   =        -1537.69 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.44 +/-  0.33 (still evaluating)
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.78488424e+01  3.03485611e-01 -1.93794488e+01 -3.79401209e-02
#   1.40555511e-01  2.49562097e+00  1.49022144e+02  1.50746132e+03
#   9.35730182e-01  9.68049143e-01  6.96514389e-01 -1.50759888e+03
#  -1.50746132e+03]
# _________________________
# lives      |    7 |  343 |
# phantoms   |  593 |11875 |
# posteriors | 8630 |10593 |
# equals     |  362 | 1240 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =               11538
# nposterior =               11538
# nequals    =                 657
# nlike      =             1972740
# <nlike>    =         208.60   (           5.96 per slice )
# log(Z)     =        -1537.20 +/-  0.28
# log(Z_1)   =        -1537.62 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.42 +/-  0.33 (still evaluating)
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.64904695e+01  3.03703000e-01 -1.94217691e+01 -3.90376880e-02
#   1.36430866e-01  2.48940028e+00  1.51732821e+02  1.50718617e+03
#   9.35559387e-01  9.68410706e-01  6.96297000e-01 -1.50722508e+03
#  -1.50718617e+03]
# _________________________
# lives      |    4 |  346 |
# phantoms   |  438 |11219 |
# posteriors | 8638 |10926 |
# equals     |  364 | 1286 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       2 /       4
# ndead      =               11879
# nposterior =               11879
# nequals    =                 676
# nlike      =             2038278
# <nlike>    =         187.25   (           5.35 per slice )
# log(Z)     =        -1537.18 +/-  0.28
# log(Z_1)   =        -1537.59 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.41 +/-  0.33 (still evaluating)
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.70948349e+01  3.07413356e-01 -1.94012708e+01 -4.15343762e-02
#   1.39413322e-01  2.45116739e+00  1.50112174e+02  1.50700233e+03
#   9.35445271e-01  9.68650421e-01  6.92586644e-01 -1.50701516e+03
#  -1.50700233e+03]
# __________________
# lives      |  350 |
# phantoms   |11536 |
# posteriors |11246 |
# equals     | 1316 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =               12204
# nposterior =               12204
# nequals    =                 683
# nlike      =             2099022
# <nlike>    =         173.55   (           4.96 per slice )
# log(Z)     =        -1537.17 +/-  0.28
# log(Z_1)   =        -1537.57 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.40 +/-  0.33
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.88968118e+01  3.04405703e-01 -1.93484062e+01 -3.39245487e-02
#   1.36571196e-01  2.47620541e+00  1.46427582e+02  1.50685882e+03
#   9.35356190e-01  9.68836511e-01  6.95594297e-01 -1.50805771e+03
#  -1.50685882e+03]
# __________________
# lives      |  350 |
# phantoms   |12147 |
# posteriors |11597 |
# equals     | 1319 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =               12555
# nposterior =               12555
# nequals    =                 690
# nlike      =             2159742
# <nlike>    =         173.49   (           4.96 per slice )
# log(Z)     =        -1537.16 +/-  0.28
# log(Z_1)   =        -1537.57 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.40 +/-  0.33
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.78638354e+01  3.06639973e-01 -1.93748691e+01 -3.98717109e-02
#   1.37538373e-01  2.48678823e+00  1.48566783e+02  1.50674155e+03
#   9.35283392e-01  9.68987915e-01  6.93360027e-01 -1.50691155e+03
#  -1.50674155e+03]
# __________________
# lives      |  350 |
# phantoms   |11753 |
# posteriors |11948 |
# equals     | 1325 |
# ‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾‾
# ncluster   =       1 /       4
# ndead      =               12906
# nposterior =               12906
# nequals    =                 690
# nlike      =             2220160
# <nlike>    =         172.62   (           4.93 per slice )
# log(Z)     =        -1537.16 +/-  0.28
# log(Z_1)   =        -1537.56 +/-  0.29 (still evaluating)
# log(Z_2)   =        -1538.40 +/-  0.33
# log(Z_3)   =        -1540.66 +/-  0.32
# log(Z_4)   =        -1541.97 +/-  0.30
#
#
#
# Last dead point: [ 6.84605619e+01  3.04857089e-01 -1.93597732e+01 -3.86516659e-02
#   1.37590608e-01  2.45023090e+00  1.47452164e+02  1.50645600e+03
#   9.35106144e-01  9.69354043e-01  6.95142911e-01 -1.50676316e+03
#  -1.50645600e+03]
#  ____________________________________________________
# |                                                    |
# | ndead  =        13372                              |
# | log(Z) =        -1537.15696 +/-            0.27796 |
# |____________________________________________________|

# %%
paramnames = [('H0','H_{0}'),('Om', r'\Omega_{m0}'),('M', r'M'),('dM', r'\Delta_{M}'),('alpha', r'\alpha'),('beta', r'\beta'),('rd','r_d (Mpc)'),('L',r'L'),('Ldof',r'L/Dof'),('p','p'),('Omega_Lambda', r'\Omega_{\Lambda0}')]
outputCCBAOPPCor.make_paramnames_files(paramnames)
posteriorCCBAOPPCor = outputCCBAOPPCor.posterior
# Out:
# chains/CC + DESI DR2 + PP.txt
# Removed no burn in

# %%
g = getdist.plots.getSubplotPlotter(width_inch=8.0)
g.settings.figure_legend_frame = True  # Remove frame around the legend
g.settings.alpha_filled_add = 0.6  # Adjust transparency of filled contours
g.settings.title_limit_fontsize = 9 # Limit title fontsize to 14
g.settings.axes_labelsize = 12  # Adjust label fontsize
g.settings.legend_fontsize = 10  # Adjust legend fontsize
g.settings.colorbar_axes_fontsize = 10  # Adjust colorbar fontsize
g.triangle_plot([posteriorCCBAOPPCor], ('H0','Om','M','dM','alpha','beta','rd') ,filled=True, contour_colors=['darkblue','red'], legend_loc='upper right', legend_labels=[r'CC + DESI DR2 + PP'],title_limit=1)
g.export("Plots/CC_BAO_PPCor_Posteriors.pdf")

# %%
def get_constraints(samples):
    for i, mean in enumerate(samples.getMeans()):
        upper = samples.confidence(i, upper=True, limfrac=0.05)
        #print("\nupper limit 95 C.L. = %f" % upper)
        lower = samples.confidence(i, upper=False, limfrac=0.05)
        #print("lower limit 95 C.L. = %f" % lower)
        print("%s = %f +/- %f +/- %f" % (samples.parLabel(i),\

        mean, mean - samples.confidence(i, limfrac=0.16),\
        mean - samples.confidence(i, limfrac=0.025)) )
    return
for i in ['CCBAOPPCor']:
    print(i)
    get_constraints(eval("posterior"+i))
# Out:
# CCBAOPPCor
# H_{0} = 68.376953 +/- 2.945622 +/- 5.729053
# \Omega_{m0} = 0.304807 +/- 0.005536 +/- 0.011312
# M = -19.364468 +/- 0.094406 +/- 0.188547
# \Delta_{M} = -0.038127 +/- 0.007445 +/- 0.014581
# \alpha = 0.137088 +/- 0.003048 +/- 0.006010
# \beta = 2.462343 +/- 0.053667 +/- 0.109080
# r_d (Mpc) = 147.942151 +/- 6.347910 +/- 11.897957
# L = 1510.079111 +/- 1.882342 +/- 2.801942
# L/Dof = 0.937355 +/- 0.001168 +/- 0.001739
# p = 0.964344 +/- 0.002747 +/- 0.007193
# \Omega_{\Lambda0} = 0.695193 +/- 0.005677 +/- 0.011230

# %%
posteriorCCBAOPPCor
